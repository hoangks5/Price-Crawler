# %%
import coinpaprika as Coinpaprika

# %%
api_client = Coinpaprika.Client()
markets = api_client.coins.markets("usdt-tether")

# %%
markets
# Out:
# [{'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ETH_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 2.8071460033433455,
#   'quotes': {'USD': {'price': 1.001304926379747,
#     'volume_24h': 1456156636.973618}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'xt',
#   'exchange_name': 'XT',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 1.3773541829583076,
#   'quotes': {'USD': {'price': 1.0013167438364796,
#     'volume_24h': 714477776.5707122}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 51)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BUSD/USDT',
#   'base_currency_id': 'busd-binance-usd',
#   'base_currency_name': 'binance usd',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/BUSD_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 1.0489893099444165,
#   'quotes': {'USD': {'price': 1.0009179666858727,
#     'volume_24h': 544144388.6319683}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'bequant',
#   'exchange_name': 'Bequant',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://bequant.io/BTC-to-USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.7402742246887661,
#   'quotes': {'USD': {'price': 0.9998794362195956,
#     'volume_24h': 384003975.6311885}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 53)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/BTC-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.7401731781828266,
#   'quotes': {'USD': {'price': 1.0000128018588865,
#     'volume_24h': 383951559.56872094}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/ETH-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.6923446754914919,
#   'quotes': {'USD': {'price': 1.0012612042150917,
#     'volume_24h': 359141381.7056712}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.6787771484733107,
#   'quotes': {'USD': {'price': 1.000391442300991,
#     'volume_24h': 352103470.42805564}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 39)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/ETH',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.6559079132393963,
#   'quotes': {'USD': {'price': 1.0000479619749139,
#     'volume_24h': 340240464.85986894}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 39)},
#  {'exchange_id': 'cryptocom-exchange',
#   'exchange_name': 'Crypto.com Exchange',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://crypto.com/exchange/trade/spot/BTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.5681501450863716,
#   'quotes': {'USD': {'price': 1.0000665045642687,
#     'volume_24h': 294717696.75667065}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 44)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/BNB_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.3504448883195502,
#   'quotes': {'USD': {'price': 1.0003405860102947,
#     'volume_24h': 181786999.82552195}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'USDC/USDT',
#   'base_currency_id': 'usdc-usd-coin',
#   'base_currency_name': 'usd coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/USDC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.33392451655831346,
#   'quotes': {'USD': {'price': 1.0007712821326509,
#     'volume_24h': 173217353.30313048}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'USDC/USDT',
#   'base_currency_id': 'usdc-usd-coin',
#   'base_currency_name': 'usd coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.3275772906226537,
#   'quotes': {'USD': {'price': 1.0007712821326509,
#     'volume_24h': 169924843.70029044}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 39)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ETC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.3163132519341944,
#   'quotes': {'USD': {'price': 1.0007651605598935,
#     'volume_24h': 164081825.67565173}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BUSD/USDT',
#   'base_currency_id': 'busd-binance-usd',
#   'base_currency_name': 'binance usd',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/BUSD-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.3027753690659997,
#   'quotes': {'USD': {'price': 1.0007878252261555,
#     'volume_24h': 157059291.76910952}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)},
#  {'exchange_id': 'p2pb2b',
#   'exchange_name': 'P2PB2B',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://p2pb2b.com/trade/BTC_USDT/',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.21874168369423796,
#   'quotes': {'USD': {'price': 1.000275740264395,
#     'volume_24h': 113468324.80917795}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 16)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'SOL/USDT',
#   'base_currency_id': 'sol-solana',
#   'base_currency_name': 'solana',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/SOL_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.21646947109780207,
#   'quotes': {'USD': {'price': 1.001117274727477,
#     'volume_24h': 112289655.28184503}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'OP/USDT',
#   'base_currency_id': 'op-optimism',
#   'base_currency_name': 'optimism',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/OP_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.20542067419930607,
#   'quotes': {'USD': {'price': 1.000221228937208,
#     'volume_24h': 106558290.0749208}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/BNB-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.18702495040637476,
#   'quotes': {'USD': {'price': 1.000609422925846,
#     'volume_24h': 97015838.32459976}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'NEAR/USDT',
#   'base_currency_id': 'near-near-protocol',
#   'base_currency_name': 'near protocol',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/NEAR_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.18304670959023792,
#   'quotes': {'USD': {'price': 0.997676289800356,
#     'volume_24h': 94952197.25961861}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'btcex',
#   'exchange_name': 'BTCEX',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.18286480026483914,
#   'quotes': {'USD': {'price': 1.0012310735943772,
#     'volume_24h': 94857835.06000687}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 29)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'AVAX/USDT',
#   'base_currency_id': 'avax-avalanche',
#   'base_currency_name': 'avalanche',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/AVAX_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.17380109114586373,
#   'quotes': {'USD': {'price': 1.0016038747987968,
#     'volume_24h': 90156198.53184797}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'cryptocom-exchange',
#   'exchange_name': 'Crypto.com Exchange',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://crypto.com/exchange/trade/spot/ETH_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.14003440355042998,
#   'quotes': {'USD': {'price': 1.001411293533146,
#     'volume_24h': 72640335.02060059}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 44)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'LINK/USDT',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/LINK_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.13791506620679303,
#   'quotes': {'USD': {'price': 1.0017318007561773,
#     'volume_24h': 71540966.78850743}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'FIL/USDT',
#   'base_currency_id': 'fil-filecoin',
#   'base_currency_name': 'filecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/FIL_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1336326490533115,
#   'quotes': {'USD': {'price': 1.0005890378580646,
#     'volume_24h': 69319539.704592}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'DOT/USDT',
#   'base_currency_id': 'dot-polkadot',
#   'base_currency_name': 'polkadot',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/DOT_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.13244217906545194,
#   'quotes': {'USD': {'price': 1.0007812997632686,
#     'volume_24h': 68702004.75205483}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'btcex',
#   'exchange_name': 'BTCEX',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1294130816417925,
#   'quotes': {'USD': {'price': 1.0006559518949134,
#     'volume_24h': 67130714.79697303}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 29)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'XRP/USDT',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/XRP_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.12439272695040468,
#   'quotes': {'USD': {'price': 1.0022005483301848,
#     'volume_24h': 64526495.851781294}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'APE/USDT',
#   'base_currency_id': 'ape-apecoin',
#   'base_currency_name': 'apecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/APE_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11960174456318899,
#   'quotes': {'USD': {'price': 1.0014406312533692,
#     'volume_24h': 62041259.67508837}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/ETC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11957711940650483,
#   'quotes': {'USD': {'price': 1.0017404749194834,
#     'volume_24h': 62028485.81676413}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 39)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ADA/USDT',
#   'base_currency_id': 'ada-cardano',
#   'base_currency_name': 'cardano',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ADA_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11910008459843056,
#   'quotes': {'USD': {'price': 1.000761584403917,
#     'volume_24h': 61781032.56673102}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.okx.com/trade-spot/etc-usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11813748076264434,
#   'quotes': {'USD': {'price': 1.000085200537771,
#     'volume_24h': 61281699.09330751}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 1)},
#  {'exchange_id': 'ftx',
#   'exchange_name': 'FTX (Spot)',
#   'pair': 'USDT/USD',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://ftx.com/trade/USDT/USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11449644315918732,
#   'quotes': {'USD': {'price': 1.0002, 'volume_24h': 59392976.146432}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 10)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'USDT/TRY',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'try-turkish-lira',
#   'quote_currency_name': 'turkish lira',
#   'market_url': 'https://www.binance.com/en/trade/USDT_TRY',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11340183702137653,
#   'quotes': {'USD': {'price': 1.00640316675,
#     'volume_24h': 58825168.846581236}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'SHIB/USDT',
#   'base_currency_id': 'shib-shiba-inu',
#   'base_currency_name': 'shiba inu',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/SHIB_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.10954178721382962,
#   'quotes': {'USD': {'price': 1.000718842611688,
#     'volume_24h': 56822837.24729367}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'DOGE/USDT',
#   'base_currency_id': 'doge-dogecoin',
#   'base_currency_name': 'dogecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/DOGE_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.10657515357816923,
#   'quotes': {'USD': {'price': 1.001082288990008,
#     'volume_24h': 55283949.26181267}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'tidex',
#   'exchange_name': 'Tidex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://tidex.com/exchange/btc/usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.10390360721441314,
#   'quotes': {'USD': {'price': 1.000786829896571,
#     'volume_24h': 53898132.505600885}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 36)},
#  {'exchange_id': 'bitforex',
#   'exchange_name': 'BitForex',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitforex.com/en/spot/eth_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0996532391982643,
#   'quotes': {'USD': {'price': 1.0008265536820165,
#     'volume_24h': 51693330.33680593}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 3)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ATOM/USDT',
#   'base_currency_id': 'atom-cosmos',
#   'base_currency_name': 'cosmos',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ATOM_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.09692787913365562,
#   'quotes': {'USD': {'price': 1.0003414011442433,
#     'volume_24h': 50279598.68854247}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'whitebit',
#   'exchange_name': 'WhiteBIT',
#   'pair': 'USDC/USDT',
#   'base_currency_id': 'usdc-usd-coin',
#   'base_currency_name': 'usd coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://whitebit.com/trade/USDC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.09285108288676006,
#   'quotes': {'USD': {'price': 1.0008713892930121,
#     'volume_24h': 48164833.761660956}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 27)},
#  {'exchange_id': 'ftx',
#   'exchange_name': 'FTX (Spot)',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://ftx.com/trade/ETH/USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.09276543012489223,
#   'quotes': {'USD': {'price': 1.0009741508023684,
#     'volume_24h': 48120402.92781035}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 10)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'FTM/USDT',
#   'base_currency_id': 'ftm-fantom',
#   'base_currency_name': 'fantom',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/FTM_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08955381266010407,
#   'quotes': {'USD': {'price': 1.0016658633768092,
#     'volume_24h': 46454433.9752864}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'FIL/USDT',
#   'base_currency_id': 'fil-filecoin',
#   'base_currency_name': 'filecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/FIL-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08853845580367763,
#   'quotes': {'USD': {'price': 1.0004046880998154,
#     'volume_24h': 45927735.81864578}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'FLOW/USDT',
#   'base_currency_id': 'flow-flow',
#   'base_currency_name': 'flow',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/FLOW_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08310440243149882,
#   'quotes': {'USD': {'price': 1.0003097864035237,
#     'volume_24h': 43108918.10337812}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'ftx',
#   'exchange_name': 'FTX (Spot)',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://ftx.com/trade/BTC/USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0817001581096187,
#   'quotes': {'USD': {'price': 1.000039652490611,
#     'volume_24h': 42380491.54957477}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 10)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'XRP/USDT',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitrue.com/trade/xrp_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08006862460643416,
#   'quotes': {'USD': {'price': 1.0016486757815446,
#     'volume_24h': 41534162.80989488}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 3)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'MATIC/USDT',
#   'base_currency_id': 'matic-polygon',
#   'base_currency_name': 'polygon',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/MATIC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07952208128427535,
#   'quotes': {'USD': {'price': 1.0011077050293944,
#     'volume_24h': 41250653.264966585}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'p2pb2b',
#   'exchange_name': 'P2PB2B',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://p2pb2b.com/trade/BNB_USDT/',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07837690790822503,
#   'quotes': {'USD': {'price': 1.0003405860102947,
#     'volume_24h': 40656615.11731233}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 16)},
#  {'exchange_id': 'bequant',
#   'exchange_name': 'Bequant',
#   'pair': 'USDT/USDC',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://bequant.io/USD-to-USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07734230012622714,
#   'quotes': {'USD': {'price': 1.0003548844440677,
#     'volume_24h': 40119930.88833868}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 53)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'USDT/USDC',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://hitbtc.com/USDT-to-USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07734230012622714,
#   'quotes': {'USD': {'price': 1.0003548844440677,
#     'volume_24h': 40119930.88833868}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'OP/USDT',
#   'base_currency_id': 'op-optimism',
#   'base_currency_name': 'optimism',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.okx.com/trade-spot/op-usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07551518509465181,
#   'quotes': {'USD': {'price': 1.0019946708324867,
#     'volume_24h': 39172147.73898559}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 1)},
#  {'exchange_id': 'cointiger',
#   'exchange_name': 'CoinTiger',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.cointiger.com/en-us/#/trade_pro?coin=btc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0754993589665415,
#   'quotes': {'USD': {'price': 1.0001630973317783,
#     'volume_24h': 39163938.21890435}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 58)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'RUNE/USDT',
#   'base_currency_id': 'rune-thorchain',
#   'base_currency_name': 'thorchain',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/RUNE_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07053666208028894,
#   'quotes': {'USD': {'price': 1.000310416806052,
#     'volume_24h': 36589628.22590856}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'dsdaq-global',
#   'exchange_name': 'Dsdaq Global',
#   'pair': 'LTC/USDT',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.dsdaq.io/en_US/trade/LTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07023950308803896,
#   'quotes': {'USD': {'price': 1.0004422557554986,
#     'volume_24h': 36435482.32887084}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ROSE/USDT',
#   'base_currency_id': 'rose-oasis-network',
#   'base_currency_name': 'oasis network',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ROSE_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06947228249894337,
#   'quotes': {'USD': {'price': 1.001186952938825,
#     'volume_24h': 36037500.410045184}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'bkex',
#   'exchange_name': 'Bkex',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bkex.com/trade/BNB_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06725529905684387,
#   'quotes': {'USD': {'price': 1.0160309473145537,
#     'volume_24h': 34887480.01586943}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 17)},
#  {'exchange_id': 'dsdaq-global',
#   'exchange_name': 'Dsdaq Global',
#   'pair': 'LINK/USDT',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.dsdaq.io/en_US/trade/LINK_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06616654097346676,
#   'quotes': {'USD': {'price': 1.0007523105501006,
#     'volume_24h': 34322706.289358586}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'LTC/USDT',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/LTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06585470968547646,
#   'quotes': {'USD': {'price': 1.0012958754276449,
#     'volume_24h': 34160949.40208507}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance-us',
#   'exchange_name': 'Binance US',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.us/en/trade/pro/BTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06504140491224752,
#   'quotes': {'USD': {'price': 1.0001249777777887,
#     'volume_24h': 33739062.13936018}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 8)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'GALA/USDT',
#   'base_currency_id': 'gala-gala',
#   'base_currency_name': 'gala',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/GALA_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06389743514336275,
#   'quotes': {'USD': {'price': 1.0019684659630603,
#     'volume_24h': 33145648.34133374}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'SAND/USDT',
#   'base_currency_id': 'sand-the-sandbox',
#   'base_currency_name': 'the sandbox',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/SAND_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06280335565946264,
#   'quotes': {'USD': {'price': 1.0001180005285417,
#     'volume_24h': 32578114.23375246}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitrue.com/trade/etc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05278889019678583,
#   'quotes': {'USD': {'price': 1.0007651605598935,
#     'volume_24h': 27383289.906178534}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 3)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'XRP/USDT',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/XRP-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.052126868210712184,
#   'quotes': {'USD': {'price': 1.0019797263519252,
#     'volume_24h': 27039877.87570508}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'NEAR/USDT',
#   'base_currency_id': 'near-near-protocol',
#   'base_currency_name': 'near protocol',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.okx.com/trade-spot/near-usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05171271235357251,
#   'quotes': {'USD': {'price': 0.9959910257973149,
#     'volume_24h': 26825041.953598723}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 1)},
#  {'exchange_id': 'tidex',
#   'exchange_name': 'Tidex',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://tidex.com/exchange/eth/usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.051469019882776856,
#   'quotes': {'USD': {'price': 1.000493529091397,
#     'volume_24h': 26698630.855527245}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 36)},
#  {'exchange_id': 'btcturk',
#   'exchange_name': 'BTCTurk',
#   'pair': 'USDT/TRY',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'try-turkish-lira',
#   'quote_currency_name': 'turkish lira',
#   'market_url': 'https://www.btcturk.com',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05130453608528952,
#   'quotes': {'USD': {'price': 1.00567933598,
#     'volume_24h': 26613307.835954864}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 10)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'CRV/USDT',
#   'base_currency_id': 'crv-curve-dao-token',
#   'base_currency_name': 'curve dao token',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/CRV_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05059365773805994,
#   'quotes': {'USD': {'price': 1.0017600323482774,
#     'volume_24h': 26244552.444476712}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'WAVES/USDT',
#   'base_currency_id': 'waves-waves',
#   'base_currency_name': 'waves',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/WAVES_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.050278205524363316,
#   'quotes': {'USD': {'price': 1.0023698456054368,
#     'volume_24h': 26080917.266942207}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ZEC/USDT',
#   'base_currency_id': 'zec-zcash',
#   'base_currency_name': 'zcash',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ZEC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04911165002174664,
#   'quotes': {'USD': {'price': 1.0004958065731644,
#     'volume_24h': 25475787.52466653}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'alterdice',
#   'exchange_name': 'Alterdice',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04871887754270369,
#   'quotes': {'USD': {'price': 1.0001037533764539,
#     'volume_24h': 25272043.846390516}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 35)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'OP/USDT',
#   'base_currency_id': 'op-optimism',
#   'base_currency_name': 'optimism',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/OP',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.048303014648635685,
#   'quotes': {'USD': {'price': 1.0012254078123002,
#     'volume_24h': 25056322.429497007}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 39)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'FIL/USDT',
#   'base_currency_id': 'fil-filecoin',
#   'base_currency_name': 'filecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/FIL',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04685544623457256,
#   'quotes': {'USD': {'price': 1.0061264413682982,
#     'volume_24h': 24305422.27998541}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 39)},
#  {'exchange_id': 'resfinex',
#   'exchange_name': 'Resfinex',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://trade.resfinex.com/?pair=ETH_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04684247142931536,
#   'quotes': {'USD': {'price': 1.0015058610872778,
#     'volume_24h': 24298691.832489554}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 40)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ENS/USDT',
#   'base_currency_id': 'ens-ethereum-name-service',
#   'base_currency_name': 'ethereum name service',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ENS_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04596204095652649,
#   'quotes': {'USD': {'price': 1.0007029188423027,
#     'volume_24h': 23841984.31716317}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'bibox',
#   'exchange_name': 'Bibox',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bibox.com/exchange?coinPair=BTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0458746123643007,
#   'quotes': {'USD': {'price': 1.0001522676175352,
#     'volume_24h': 23796632.303167738}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 17, 31)},
#  {'exchange_id': 'bitfinex',
#   'exchange_name': 'Bitfinex',
#   'pair': 'USDT/USD',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://www.bitfinex.com/t/UST:USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04567261054790597,
#   'quotes': {'USD': {'price': 0.99997, 'volume_24h': 23691847.4842543}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'BAT/USDT',
#   'base_currency_id': 'bat-basic-attention-token',
#   'base_currency_name': 'basic attention token',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitrue.com/trade/bat_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04523456685716112,
#   'quotes': {'USD': {'price': 1.0010326682914084,
#     'volume_24h': 23464620.17694544}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 3)},
#  {'exchange_id': 'bkex',
#   'exchange_name': 'Bkex',
#   'pair': 'LINK/USDT',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bkex.com/trade/LINK_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04453005426674606,
#   'quotes': {'USD': {'price': 1.0135880467071565,
#     'volume_24h': 23099166.90763115}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 17)},
#  {'exchange_id': 'deepcoin',
#   'exchange_name': 'Deepcoin',
#   'pair': 'DOT/USDT',
#   'base_currency_id': 'dot-polkadot',
#   'base_currency_name': 'polkadot',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.044150613797567954,
#   'quotes': {'USD': {'price': 1.0007812997632686,
#     'volume_24h': 22902338.970333975}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 21)},
#  {'exchange_id': 'deepcoin',
#   'exchange_name': 'Deepcoin',
#   'pair': 'LINK/USDT',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04407563202184161,
#   'quotes': {'USD': {'price': 1.0016122480887046,
#     'volume_24h': 22863443.519136943}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 21)},
#  {'exchange_id': 'deepcoin',
#   'exchange_name': 'Deepcoin',
#   'pair': 'FIL/USDT',
#   'base_currency_id': 'fil-filecoin',
#   'base_currency_name': 'filecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.043739999994899,
#   'quotes': {'USD': {'price': 1.0005890378580646,
#     'volume_24h': 22689340.425449867}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 21)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'TRX/USDT',
#   'base_currency_id': 'trx-tron',
#   'base_currency_name': 'tron',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/TRX_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04275604342684764,
#   'quotes': {'USD': {'price': 1.0021605845865478,
#     'volume_24h': 22178930.605171446}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'RSR/USDT',
#   'base_currency_id': 'rsr-reserve-rights',
#   'base_currency_name': 'reserve rights',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/RSR_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04256339051929544,
#   'quotes': {'USD': {'price': 1.0025276402576984,
#     'volume_24h': 22078995.365027085}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'counos-exchange',
#   'exchange_name': 'Counos Exchange',
# ...
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 55)},
#  {'exchange_id': 'betconix',
#   'exchange_name': 'BETCONIX',
#   'pair': 'LINK/USDT',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0013008359325158514,
#   'quotes': {'USD': {'price': 1.001754638561855,
#     'volume_24h': 674785.3066747088}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 55)},
#  {'exchange_id': 'bibox',
#   'exchange_name': 'Bibox',
#   'pair': 'UNI/USDT',
#   'base_currency_id': 'uni-uniswap',
#   'base_currency_name': 'uniswap',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bibox.com/exchange?coinPair=UNI_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0013007935059319458,
#   'quotes': {'USD': {'price': 1.001459881112762,
#     'volume_24h': 674763.2986453207}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 17, 31)},
#  {'exchange_id': 'betconix',
#   'exchange_name': 'BETCONIX',
#   'pair': 'ZEC/USDT',
#   'base_currency_id': 'zec-zcash',
#   'base_currency_name': 'zcash',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012979948230959395,
#   'quotes': {'USD': {'price': 1.0033169016408872,
#     'volume_24h': 673311.5321245979}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 55)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'STRAX/USDT',
#   'base_currency_id': 'strax-stratis',
#   'base_currency_name': 'stratis',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/STRAT_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012919701940763064,
#   'quotes': {'USD': {'price': 1.0012938455268607,
#     'volume_24h': 670186.3638854703}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'THETA/USDT',
#   'base_currency_id': 'theta-theta-token',
#   'base_currency_name': 'theta',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/theta_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001285025674729963,
#   'quotes': {'USD': {'price': 1.0013380967188135,
#     'volume_24h': 666584.0190395928}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 24)},
#  {'exchange_id': 'huobi',
#   'exchange_name': 'Huobi',
#   'pair': 'IOST/USDT',
#   'base_currency_id': 'iost-iost',
#   'base_currency_name': 'iost',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.hbg.com/en-us/exchange/?s=iost_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012845981604688982,
#   'quotes': {'USD': {'price': 1.0037459453183828,
#     'volume_24h': 666362.2536850623}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 12)},
#  {'exchange_id': 'coinsbit',
#   'exchange_name': 'Coinsbit',
#   'pair': 'YFI/USDT',
#   'base_currency_id': 'yfi-yearnfinance',
#   'base_currency_name': 'yearn.finance',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://coinsbit.io/trade/YFI_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012819837773330467,
#   'quotes': {'USD': {'price': 0.9999584324875482,
#     'volume_24h': 665006.0893279793}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 11)},
#  {'exchange_id': 'huobi',
#   'exchange_name': 'Huobi',
#   'pair': 'THETA/USDT',
#   'base_currency_id': 'theta-theta-token',
#   'base_currency_name': 'theta',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.hbg.com/en-us/exchange/?s=theta_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012795623814251165,
#   'quotes': {'USD': {'price': 1.0004839369250245,
#     'volume_24h': 663750.0336337354}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 12)},
#  {'exchange_id': 'bitmart',
#   'exchange_name': 'BitMart',
#   'pair': 'XLM/USDT',
#   'base_currency_id': 'xlm-stellar',
#   'base_currency_name': 'stellar',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitmart.com/trade/en?layout=basic&symbol=XLM_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012790698891102022,
#   'quotes': {'USD': {'price': 0.999436894238279,
#     'volume_24h': 663494.5620792931}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)},
#  {'exchange_id': 'huobi',
#   'exchange_name': 'Huobi',
#   'pair': 'HBAR/USDT',
#   'base_currency_id': 'hbar-hedera-hashgraph',
#   'base_currency_name': 'hedera hashgraph',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.hbg.com/en-us/exchange/?s=hbar_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012764468540764145,
#   'quotes': {'USD': {'price': 1.000611900102738,
#     'volume_24h': 662133.9097053462}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 12)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'KOK/USDT',
#   'base_currency_id': 'kok-kok-coin',
#   'base_currency_name': 'kok coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.kucoin.com/trade/KOK-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012710544095366674,
#   'quotes': {'USD': {'price': 0.995496801020539,
#     'volume_24h': 659336.6758255578}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 2)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'ANC/USDT',
#   'base_currency_id': 'anc-anchor-protocol',
#   'base_currency_name': 'anchor protocol',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.kucoin.com/trade/ANC-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012697855360398816,
#   'quotes': {'USD': {'price': 0.9996996959859383,
#     'volume_24h': 658678.4704591023}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 2)},
#  {'exchange_id': 'coinsbit',
#   'exchange_name': 'Coinsbit',
#   'pair': 'COMP/USDT',
#   'base_currency_id': 'comp-compoundd',
#   'base_currency_name': 'compound',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://coinsbit.io/trade/COMP_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001269300758453934,
#   'quotes': {'USD': {'price': 1.0009766089319065,
#     'volume_24h': 658427.000781931}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 11)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'MDX/USDT',
#   'base_currency_id': 'mdx-mdex',
#   'base_currency_name': 'mdex',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/MDX_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001268685305418055,
#   'quotes': {'USD': {'price': 0.9993473979299076,
#     'volume_24h': 658107.7455590557}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'XDC/USDT',
#   'base_currency_id': 'xdc-xdc-network',
#   'base_currency_name': 'xdc network',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.kucoin.com/trade/XDC-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001267125027808911,
#   'quotes': {'USD': {'price': 1.0011579733040898,
#     'volume_24h': 657298.3795362801}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 2)},
#  {'exchange_id': 'coinex',
#   'exchange_name': 'CoinEx',
#   'pair': 'DOGE/USDT',
#   'base_currency_id': 'doge-dogecoin',
#   'base_currency_name': 'dogecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.coinex.com/exchange?currency=usdt&dest=doge#limit',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012664072532753846,
#   'quotes': {'USD': {'price': 1.0009797445993716,
#     'volume_24h': 656926.0468718585}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 57)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'XDC/USDT',
#   'base_currency_id': 'xdc-xdc-network',
#   'base_currency_name': 'xdc network',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitrue.com/trade/xdc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012646281304304833,
#   'quotes': {'USD': {'price': 0.9993573294672121,
#     'volume_24h': 656003.1588084985}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 3)},
#  {'exchange_id': 'cointiger',
#   'exchange_name': 'CoinTiger',
#   'pair': 'DOGE/USDT',
#   'base_currency_id': 'doge-dogecoin',
#   'base_currency_name': 'dogecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.cointiger.com/en-us/#/trade_pro?coin=doge_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012615765053770494,
#   'quotes': {'USD': {'price': 1.0004439258235232,
#     'volume_24h': 654420.1830495532}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 58)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'MC/USDT',
#   'base_currency_id': 'mc-merit-circle',
#   'base_currency_name': 'merit circle',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/MC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001261189905531599,
#   'quotes': {'USD': {'price': 0.9903322209711347,
#     'volume_24h': 654219.6413142337}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'AZERO/USDT',
#   'base_currency_id': 'azero-aleph-zero',
#   'base_currency_name': 'aleph zero',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/azero_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001258650330950861,
#   'quotes': {'USD': {'price': 1.0021090481885557,
#     'volume_24h': 652902.282553262}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 24)},
#  {'exchange_id': 'bitmart',
#   'exchange_name': 'BitMart',
#   'pair': 'LTC/USDT',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitmart.com/trade/en?layout=basic&symbol=LTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012488518372697416,
#   'quotes': {'USD': {'price': 1.0009542528157624,
#     'volume_24h': 647819.489713448}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'ENS/USDT',
#   'base_currency_id': 'ens-ethereum-name-service',
#   'base_currency_name': 'ethereum name service',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.kucoin.com/trade/ENS-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012487469986959285,
#   'quotes': {'USD': {'price': 0.9999867824746449,
#     'volume_24h': 647765.10658379}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 2)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'ICX/USDT',
#   'base_currency_id': 'icx-icon',
#   'base_currency_name': 'icon',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.okx.com/trade-spot/icx-usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012460757878901857,
#   'quotes': {'USD': {'price': 1.0118714810838236,
#     'volume_24h': 646379.4638922786}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 1)},
#  {'exchange_id': 'arthbit',
#   'exchange_name': 'ArthBit',
#   'pair': 'XRP/USDT',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012445337610543263,
#   'quotes': {'USD': {'price': 1.0016486757815446,
#     'volume_24h': 645579.5651307771}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)},
#  {'exchange_id': 'hotbit',
#   'exchange_name': 'Hotbit',
#   'pair': 'UNI/USDT',
#   'base_currency_id': 'uni-uniswap',
#   'base_currency_name': 'uniswap',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.hotbit.io/exchange?symbol=UNI_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012438629814055925,
#   'quotes': {'USD': {'price': 1.0000184216331047,
#     'volume_24h': 645231.6102198865}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 46)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'LAT/USDT',
#   'base_currency_id': 'lat-platon-network',
#   'base_currency_name': 'platon network',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.okx.com/trade-spot/lat-usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012389364737988035,
#   'quotes': {'USD': {'price': 0.9963382427617443,
#     'volume_24h': 642676.0727664791}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 1)},
#  {'exchange_id': 'coinex',
#   'exchange_name': 'CoinEx',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.coinex.com/exchange?currency=usdt&dest=etc#limit',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012312266295014295,
#   'quotes': {'USD': {'price': 1.001527814321139,
#     'volume_24h': 638676.7293300197}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 57)},
#  ...]

# %%
for i in markets:
    if i['pair'] == 'DOGE/USDT':
        print(i)
# Out:
# {'exchange_id': 'binance', 'exchange_name': 'Binance', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.binance.com/en/trade/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.10657515357816923, 'quotes': {'USD': {'price': 1.001082288990008, 'volume_24h': 55283949.26181267}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)}
# {'exchange_id': 'okx', 'exchange_name': 'OKX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.okx.com/trade-spot/doge-usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.028520740723143923, 'quotes': {'USD': {'price': 1.0002040182290868, 'volume_24h': 14794622.66869847}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 1)}
# {'exchange_id': 'gateio', 'exchange_name': 'Gate.io', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.gate.io/trade/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.027574374814894807, 'quotes': {'USD': {'price': 1.0008918661265565, 'volume_24h': 14303712.328922331}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 24)}
# {'exchange_id': 'digifinex', 'exchange_name': 'DigiFinex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/DOGE', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.020312917164385068, 'quotes': {'USD': {'price': 1.0016393253483167, 'volume_24h': 10536961.422735384}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 39)}
# {'exchange_id': 'deepcoin', 'exchange_name': 'Deepcoin', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.010049198113193315, 'quotes': {'USD': {'price': 1.0015220030261678, 'volume_24h': 5212841.26702383}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 21)}
# {'exchange_id': 'huobi', 'exchange_name': 'Huobi', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.hbg.com/en-us/exchange/?s=doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.004961090044038474, 'quotes': {'USD': {'price': 1.0006868763504433, 'volume_24h': 2573476.4724194403}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 12)}
# {'exchange_id': 'p2pb2b', 'exchange_name': 'P2PB2B', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://p2pb2b.com/trade/DOGE_USDT/', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.004396689590564112, 'quotes': {'USD': {'price': 1.000642960893611, 'volume_24h': 2280703.8609276363}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 16)}
# {'exchange_id': 'dex-trade', 'exchange_name': 'Dex-Trade', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.004362889482463179, 'quotes': {'USD': {'price': 1.0015220030261678, 'volume_24h': 2263170.6611286304}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 27)}
# {'exchange_id': 'bibox', 'exchange_name': 'Bibox', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bibox.com/exchange?coinPair=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.003606043789843614, 'quotes': {'USD': {'price': 1.0013900482613896, 'volume_24h': 1870570.5337536107}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 17, 31)}
# {'exchange_id': 'hotbit', 'exchange_name': 'Hotbit', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.hotbit.io/exchange?symbol=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0035403065628506203, 'quotes': {'USD': {'price': 1.0024025909537992, 'volume_24h': 1836470.5263909441}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 46)}
# {'exchange_id': 'tidex', 'exchange_name': 'Tidex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://tidex.com/exchange/doge/usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0028715394374148255, 'quotes': {'USD': {'price': 1.000185006085383, 'volume_24h': 1489559.5758620945}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 36)}
# {'exchange_id': 'btcix', 'exchange_name': 'Btcix', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://btcix.io/Trade/index/market/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0028286835583678223, 'quotes': {'USD': {'price': 1.0002040182290868, 'volume_24h': 1467328.8573197362}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 21)}
# {'exchange_id': 'ftx', 'exchange_name': 'FTX (Spot)', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://ftx.com/trade/DOGE/USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.002715460438988293, 'quotes': {'USD': {'price': 0.9999335288259098, 'volume_24h': 1408596.395044174}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 10)}
# {'exchange_id': 'bitmart', 'exchange_name': 'BitMart', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bitmart.com/trade/en?layout=basic&symbol=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0023378244025488402, 'quotes': {'USD': {'price': 1.0002332690923443, 'volume_24h': 1212704.474863754}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)}
# {'exchange_id': 'betconix', 'exchange_name': 'BETCONIX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0013642480443195439, 'quotes': {'USD': {'price': 1.0046989405105315, 'volume_24h': 707679.2022389169}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 55)}
# {'exchange_id': 'coinex', 'exchange_name': 'CoinEx', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.coinex.com/exchange?currency=usdt&dest=doge#limit', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0012664072532753846, 'quotes': {'USD': {'price': 1.0009797445993716, 'volume_24h': 656926.0468718585}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 57)}
# {'exchange_id': 'cointiger', 'exchange_name': 'CoinTiger', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.cointiger.com/en-us/#/trade_pro?coin=doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0012615765053770494, 'quotes': {'USD': {'price': 1.0004439258235232, 'volume_24h': 654420.1830495532}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 58)}
# {'exchange_id': 'arthbit', 'exchange_name': 'ArthBit', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0010660063918654786, 'quotes': {'USD': {'price': 1.000642960893611, 'volume_24h': 552971.6946401936}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)}
# {'exchange_id': 'oceanex', 'exchange_name': 'OceanEx', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0007929787771154263, 'quotes': {'USD': {'price': 1.0009226218368101, 'volume_24h': 411343.5168318954}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 15)}
# {'exchange_id': 'bitfinex', 'exchange_name': 'Bitfinex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bitfinex.com/t/DOGE::UST', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0003953459278573962, 'quotes': {'USD': {'price': 0.9999554549488686, 'volume_24h': 205078.60868810955}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)}
# {'exchange_id': 'bigone', 'exchange_name': 'BigONE', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://big.one/trade/DOGE-USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0003143813279104515, 'quotes': {'USD': {'price': 1.0027993609236838, 'volume_24h': 163079.67474158865}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 17)}
# {'exchange_id': 'binance-us', 'exchange_name': 'Binance US', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.binance.us/en/trade/pro/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0002982702969688121, 'quotes': {'USD': {'price': 1.0024466610004432, 'volume_24h': 154722.36642694662}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 8)}
# {'exchange_id': 'poloniex', 'exchange_name': 'Poloniex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://poloniex.com/exchange/#usdt_doge', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0002942466039463414, 'quotes': {'USD': {'price': 0.9974620549839197, 'volume_24h': 152635.14784521383}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 27)}
# {'exchange_id': 'tarmex', 'exchange_name': 'Tarmex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.0500995500843165e-05, 'quotes': {'USD': {'price': 1.0010969399038072, 'volume_24h': 26196.485571018995}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 10)}
# {'exchange_id': 'bittrex', 'exchange_name': 'Bittrex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://bittrex.com/Market/Index?MarketName=USDT-DOGE', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.668291978591882e-05, 'quotes': {'USD': {'price': 1.0018203489397464, 'volume_24h': 19028.606651103055}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 49)}
# {'exchange_id': 'bitforex', 'exchange_name': 'BitForex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bitforex.com/en/spot/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.236607609750435e-05, 'quotes': {'USD': {'price': 0.9993729853050584, 'volume_24h': 16789.321419705862}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 3)}
# {'exchange_id': 'nicehash', 'exchange_name': 'NiceHash', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 2.8194994570360174e-06, 'quotes': {'USD': {'price': 0.9975784279814386, 'volume_24h': 1462.5647694906677}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 39)}
# {'exchange_id': 'upbit', 'exchange_name': 'Upbit', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://upbit.com/exchange?code=CRIX.UPBIT.USDT-DOGE', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 2.5389046696298383e-06, 'quotes': {'USD': {'price': 1.019661983797065, 'volume_24h': 1317.0112566006815}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 23)}
# {'exchange_id': 'coinamount', 'exchange_name': 'CoinAmount', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 2.4558249624713717e-06, 'quotes': {'USD': {'price': 1.0019621035108723, 'volume_24h': 1273.9151487272254}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 26)}
# {'exchange_id': 'zonda', 'exchange_name': 'Zonda', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://app.bitbay.net/market/doge-usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.8183208062531202e-06, 'quotes': {'USD': {'price': 1.0055116613016102, 'volume_24h': 943.2213027107199}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 52)}
# {'exchange_id': 'hitbtc', 'exchange_name': 'HitBTC', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://hitbtc.com/DOGE-to-USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.2740862449186528e-06, 'quotes': {'USD': {'price': 4.557225370199017, 'volume_24h': 660.90938604741}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 48)}
# {'exchange_id': 'bitubu', 'exchange_name': 'BitUBU', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://bitubu.com/trading/dogeusdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.116804637277706e-06, 'quotes': {'USD': {'price': 1.0002040182290868, 'volume_24h': 579.3223732709203}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 41)}
# {'exchange_id': 'yobit', 'exchange_name': 'YoBit', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://yobit.net/en/trade/DOGE/USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.0338326240190599e-06, 'quotes': {'USD': {'price': 1.0059357486359954, 'volume_24h': 536.2821296762722}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 15, 9)}
# {'exchange_id': 'novadax', 'exchange_name': 'NovaDAX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 7.588181282047071e-07, 'quotes': {'USD': {'price': 1.0093544755302826, 'volume_24h': 393.6232929548956}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 25)}
# {'exchange_id': 'xbts', 'exchange_name': 'XBTS', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.303311247301221e-08, 'quotes': {'USD': {'price': 0.9913616348795252, 'volume_24h': 6.760693318194722}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 12)}
# {'exchange_id': 'exchangeassets', 'exchange_name': 'ExchangeAssets', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 9.422671017002158e-10, 'quotes': {'USD': {'price': 0.9435027973336173, 'volume_24h': 0.4887841573998965}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 22)}
# {'exchange_id': 'binance-futures', 'exchange_name': 'Binance Futures', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Derivatives', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.0019621035108723, 'volume_24h': 214171504.76761112}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 38)}
# {'exchange_id': 'bkex', 'exchange_name': 'Bkex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bkex.com/trade/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': True, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.0260079917007239, 'volume_24h': 17792727.241735484}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 10, 11, 14, 17)}
# {'exchange_id': 'catex', 'exchange_name': 'Catex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.catex.io/trading/DOGE/USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.004353746668506131, 'quotes': {'USD': {'price': 1.0006575989509392, 'volume_24h': 2258427.9903846383}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 12)}
# {'exchange_id': 'latoken', 'exchange_name': 'LATOKEN', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.004352324872605431, 'quotes': {'USD': {'price': 1.0012273519313826, 'volume_24h': 2257690.459264148}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 45)}
# {'exchange_id': 'huobi-korea', 'exchange_name': 'Huobi Korea', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.huobi.co.kr/en-US/exchange/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0002188592842816992, 'quotes': {'USD': {'price': 1.0008479326761952, 'volume_24h': 113529.3280045015}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 31)}
# {'exchange_id': 'exbitron', 'exchange_name': 'Exbitron', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 4.7255612266448385e-07, 'quotes': {'USD': {'price': 0.8965488638955897, 'volume_24h': 245.13001231174047}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 58)}
# {'exchange_id': 'dsdaq-global', 'exchange_name': 'Dsdaq Global', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.dsdaq.io/en_US/trade/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.027077449470944398, 'quotes': {'USD': {'price': 1.0008630160593712, 'volume_24h': 14045941.220183428}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)}
# {'exchange_id': 'zbcom', 'exchange_name': 'ZB.COM', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://trans.zb.com/dogeusdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.007666665552037431, 'quotes': {'USD': {'price': 1.0725337900226763, 'volume_24h': 3976945.236820604}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 8)}
# {'exchange_id': 'counos-exchange', 'exchange_name': 'Counos Exchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://counos.exchange/spot/trading/DOGEUSDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.001613115273765646, 'quotes': {'USD': {'price': 1.001082288990008, 'volume_24h': 836774.613539778}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 24)}
# {'exchange_id': 'bw', 'exchange_name': 'BW', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bw.com/trade/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0012113860489660422, 'quotes': {'USD': {'price': 1.0077722567296916, 'volume_24h': 628384.7840611936}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 6)}
# {'exchange_id': 'bittilo', 'exchange_name': 'Bittilo', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 9.16606109720972e-05, 'quotes': {'USD': {'price': 1.004389586765836, 'volume_24h': 47547.29780962911}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 41)}
# {'exchange_id': 'crex24', 'exchange_name': 'Crex24', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://crex24.com/exchange/DOGE-USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.8986502779194334e-08, 'quotes': {'USD': {'price': 0.6840395280668725, 'volume_24h': 20.223549009100317}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 15)}
# {'exchange_id': 'mexc', 'exchange_name': 'MEXC', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.mexc.com/exchange/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.029813586253054043, 'quotes': {'USD': {'price': 1.0006634542937867, 'volume_24h': 15465263.097346682}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 31)}
# {'exchange_id': 'zedxion-exchange', 'exchange_name': 'ZEDXION EXCHANGE', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.027092904120105888, 'quotes': {'USD': {'price': 1.0002756858831419, 'volume_24h': 14053958.042223252}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 36)}
# {'exchange_id': 'bitexlive', 'exchange_name': 'Bitexlive', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://bitexlive.com/exchange/USDT-DOGE', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0027048529010240464, 'quotes': {'USD': {'price': 1.0181625824532456, 'volume_24h': 1403093.9249944543}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 22)}
# {'exchange_id': 'btc-alpha', 'exchange_name': 'BTC-Alpha', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://btc-alpha.com/exchange/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0025479502728681905, 'quotes': {'USD': {'price': 1.0042126459868645, 'volume_24h': 1321703.5010280353}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 42)}
# {'exchange_id': 'zbg', 'exchange_name': 'ZBG', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.zbg.com/trade/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0022661160202762645, 'quotes': {'USD': {'price': 1.0729678364585205, 'volume_24h': 1175507.0378054432}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 14)}
# {'exchange_id': 'btc6x-exchange', 'exchange_name': 'BTC6X Exchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.001583871393946722, 'quotes': {'USD': {'price': 1.0004966038713947, 'volume_24h': 821604.875436214}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 6)}
# {'exchange_id': 'bitcom', 'exchange_name': 'Bit.com', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0015687207492417173, 'quotes': {'USD': {'price': 1.0015220030261678, 'volume_24h': 813745.750255213}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 46)}
# {'exchange_id': 'hollaex', 'exchange_name': 'HollaEx', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.00134587197668449, 'quotes': {'USD': {'price': 1.004389586765836, 'volume_24h': 698146.9467679188}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 3)}
# {'exchange_id': 'gokumarket', 'exchange_name': 'GokuMarket', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://gokumarket.com/exchange/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0012529329236329002, 'quotes': {'USD': {'price': 1.0244713614899992, 'volume_24h': 649936.4800611885}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 34)}
# {'exchange_id': 'decoin', 'exchange_name': 'Decoin', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0010639239554115496, 'quotes': {'USD': {'price': 0.9987436531856804, 'volume_24h': 551891.4680827388}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 26)}
# {'exchange_id': 'criptoswaps', 'exchange_name': 'Criptoswaps', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0003506042151184034, 'quotes': {'USD': {'price': 1.000057789571451, 'volume_24h': 181869.64774455485}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 19)}
# {'exchange_id': 'smartfi', 'exchange_name': 'SmartFi', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.00028272141436007104, 'quotes': {'USD': {'price': 0.9981607005207538, 'volume_24h': 146656.6624766442}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 15)}
# {'exchange_id': 'bitunivex', 'exchange_name': 'Bitunivex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 9.16606109720972e-05, 'quotes': {'USD': {'price': 1.004389586765836, 'volume_24h': 47547.29780962911}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 25)}
# {'exchange_id': 'krypterz', 'exchange_name': 'Krypterz', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 9.16606109720972e-05, 'quotes': {'USD': {'price': 1.004389586765836, 'volume_24h': 47547.29780962911}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 6)}
# {'exchange_id': 'patriot-exchange', 'exchange_name': 'Patriot Exchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 9.16606109720972e-05, 'quotes': {'USD': {'price': 1.004389586765836, 'volume_24h': 47547.29780962911}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 4)}
# {'exchange_id': 'garts-exchange', 'exchange_name': 'Garts Exchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.081283759236007e-05, 'quotes': {'USD': {'price': 0.9999116036644826, 'volume_24h': 26358.248062428152}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 6)}
# {'exchange_id': 'cex-trade', 'exchange_name': 'Cex-Trade', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 4.273411343329492e-05, 'quotes': {'USD': {'price': 1.0003502896561458, 'volume_24h': 22167.554814378036}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 46)}
# {'exchange_id': '365-stream', 'exchange_name': '365 stream', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.7015586200886285e-05, 'quotes': {'USD': {'price': 1.0002040182290868, 'volume_24h': 19201.17138677272}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 47)}
# {'exchange_id': 'dasset', 'exchange_name': 'Dasset', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.668291978591882e-05, 'quotes': {'USD': {'price': 1.0018203489397464, 'volume_24h': 19028.606651103055}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 54)}
# {'exchange_id': 'xeggex', 'exchange_name': 'Xeggex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.916806102976016e-06, 'quotes': {'USD': {'price': 1.005940482451283, 'volume_24h': 3069.2370351499403}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 12)}
# {'exchange_id': 'graviex', 'exchange_name': 'Graviex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://graviex.net/markets/dogeusdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.2920633353037888e-06, 'quotes': {'USD': {'price': 0.9771993258098177, 'volume_24h': 670.2346792265365}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 54)}
# {'exchange_id': 'fatbtc', 'exchange_name': 'Fatbtc', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.fatbtc.com', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 9.012993408640473e-07, 'quotes': {'USD': {'price': 0.9519985638273594, 'volume_24h': 467.53286631190747}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 13)}
# {'exchange_id': 'southxchange', 'exchange_name': 'SouthXchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.southxchange.com/Market/Book/DOGE/USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.763007356841875e-08, 'quotes': {'USD': {'price': 0.9998531412676827, 'volume_24h': 29.894566943074203}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 14)}
# {'exchange_id': 'bololex', 'exchange_name': 'Bololex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.775783476925248e-08, 'quotes': {'USD': {'price': 1.0688117626044882, 'volume_24h': 9.211558261212796}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 56)}
# {'exchange_id': 'zebitex', 'exchange_name': 'ZEBITEX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 8.279350909256706e-09, 'quotes': {'USD': {'price': 0.8449627726059536, 'volume_24h': 4.294764776035457}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 42)}
# {'exchange_id': 'satoexchange', 'exchange_name': 'SatoExchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.790074654451534e-10, 'quotes': {'USD': {'price': 0.0760060810314532, 'volume_24h': 0.30034973694316575}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 30)}
# {'exchange_id': 'vindax', 'exchange_name': 'VinDAX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://vindax.com/exchange-base.html?symbol=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 4.516258242738353e-10, 'quotes': {'USD': {'price': 0.8769737539318878, 'volume_24h': 0.23427279545195415}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 39)}
# {'exchange_id': 'apollox', 'exchange_name': 'ApolloX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Derivatives', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.0004966038713947, 'volume_24h': 161414.05635317383}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 12)}
# {'exchange_id': 'bankcex', 'exchange_name': 'BankCEX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://bankcex.com/exchange-base.html?symbol=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 0.4560263520445817, 'volume_24h': 0}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 39)}
# {'exchange_id': 'exchangily', 'exchange_name': 'eXchangily', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 0.17100988201671813, 'volume_24h': 0}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 8)}
# {'exchange_id': 'altmarkets', 'exchange_name': 'AltMarkets', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 0.8550494100835906, 'volume_24h': 0}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 10, 11, 18, 5)}

# %%
api_client = Coinpaprika.Client()
btc_ticker = api_client.tickers.for_coin("doge-dogecoin")

# %%
btc_ticker
# Out:
# {'id': 'doge-dogecoin',
#  'name': 'Dogecoin',
#  'symbol': 'DOGE',
#  'rank': 11,
#  'circulating_supply': 132670764300,
#  'total_supply': 132670764300,
#  'max_supply': 0,
#  'beta_value': 1.06227,
#  'first_data_at': datetime.datetime(2013, 12, 15, 0, 0),
#  'last_updated': datetime.datetime(2022, 8, 10, 9, 53, 29),
#  'quotes': {'USD': {'price': 0.0685101251421323,
#    'volume_24h': 324293326.2286597,
#    'volume_24h_change_24h': -17.57,
#    'market_cap': 9089290665,
#    'market_cap_change_24h': -3.38,
#    'percent_change_15m': 0.02,
#    'percent_change_30m': -0.21,
#    'percent_change_1h': -0.08,
#    'percent_change_6h': 0.51,
#    'percent_change_12h': -1.15,
#    'percent_change_24h': -3.38,
#    'percent_change_7d': 0.87,
#    'percent_change_30d': 11.19,
#    'percent_change_1y': -74.32,
#    'ath_price': 0.75287027,
#    'ath_date': '2021-05-08T05:02:22Z',
#    'percent_from_price_ath': -90.9}}}
