# %%
import coinpaprika as Coinpaprika

# %%
api_client = Coinpaprika.Client()
markets = api_client.coins.markets("btc-bitcoin")

# %%
markets
# Out:
# [{'exchange_id': 'coinbase',
#   'exchange_name': 'Coinbase',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://pro.coinbase.com/trade/BTC-USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 1.7257657452214157,
#   'quotes': {'USD': {'price': 22965.06, 'volume_24h': 536133263.01877207}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 21)},
#  {'exchange_id': 'bequant',
#   'exchange_name': 'Bequant',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://bequant.io/BTC-to-USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 1.5276488810600326,
#   'quotes': {'USD': {'price': 22979.518562531663,
#     'volume_24h': 474585488.567923}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 39)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/BTC-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 1.5276488810600326,
#   'quotes': {'USD': {'price': 22979.518562531663,
#     'volume_24h': 474585488.567923}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 56)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 1.2812475728625028,
#   'quotes': {'USD': {'price': 22989.358663432373,
#     'volume_24h': 398037476.33519274}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 38)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/ETH_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.48732380059574015,
#   'quotes': {'USD': {'price': 22990.85848298157,
#     'volume_24h': 151393953.71796685}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 7)},
#  {'exchange_id': 'primexbt',
#   'exchange_name': 'PrimeXBT',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.48093637889975605,
#   'quotes': {'USD': {'price': 22964.9, 'volume_24h': 149409611.84212002}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 36)},
#  {'exchange_id': 'binance-us',
#   'exchange_name': 'Binance US',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://www.binance.us/en/trade/pro/BTC_USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.47848242426775367,
#   'quotes': {'USD': {'price': 22964.64, 'volume_24h': 148647256.51794094}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 52)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://www.binance.com/en/trade/BTC_USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.4433143530453025,
#   'quotes': {'USD': {'price': 22976.096170538094,
#     'volume_24h': 137721803.37878948}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'bitfinex',
#   'exchange_name': 'Bitfinex',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://www.bitfinex.com/t/BTC:USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.39609724762068277,
#   'quotes': {'USD': {'price': 22958, 'volume_24h': 123053149.26295821}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 35)},
#  {'exchange_id': 'p2pb2b',
#   'exchange_name': 'P2PB2B',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://p2pb2b.com/trade/BTC_USDT/',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.39442013029972295,
#   'quotes': {'USD': {'price': 22965.65433084551,
#     'volume_24h': 122532129.31326851}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 49)},
#  {'exchange_id': 'btse',
#   'exchange_name': 'BTSE',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://www.btse.com/en/trading/BTC-USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.3537494020701121,
#   'quotes': {'USD': {'price': 22960.5, 'volume_24h': 109897198.82199642}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 43)},
#  {'exchange_id': 'currency-com',
#   'exchange_name': 'Currency.com',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://currency.com/btc-to-usd',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.2908362078405783,
#   'quotes': {'USD': {'price': 22967.5, 'volume_24h': 90352335.2142846}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 55)},
#  {'exchange_id': 'tidex',
#   'exchange_name': 'Tidex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://tidex.com/exchange/btc/usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1828558831695225,
#   'quotes': {'USD': {'price': 22982.746873645203,
#     'volume_24h': 56806737.28593307}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 44)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDC/BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.17893418493804172,
#   'quotes': {'USD': {'price': 22977.216603385907,
#     'volume_24h': 55588406.88666502}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 38)},
#  {'exchange_id': 'coinsbit',
#   'exchange_name': 'Coinsbit',
#   'pair': 'BTC/BUSD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'busd-binance-usd',
#   'quote_currency_name': 'binance usd',
#   'market_url': 'https://coinsbit.io/trade/BTC_BUSD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.171099731241479,
#   'quotes': {'USD': {'price': 22968.741293252093,
#     'volume_24h': 53154524.28357235}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 3)},
#  {'exchange_id': 'coincheck',
#   'exchange_name': 'coincheck',
#   'pair': 'BTC/JPY',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'jpy-japanese-yen',
#   'quote_currency_name': 'japanese yen',
#   'market_url': 'https://coincheck.com',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.15302122999041692,
#   'quotes': {'USD': {'price': 22995.540741239998,
#     'volume_24h': 47538185.04804226}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 39)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BTC/EUR',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'eur-euro',
#   'quote_currency_name': 'euro',
#   'market_url': 'https://www.binance.com/en/trade/BTC_EUR',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.14528857125847894,
#   'quotes': {'USD': {'price': 22985.016945763597,
#     'volume_24h': 45135926.47427933}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'xt',
#   'exchange_name': 'XT',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1423622771596364,
#   'quotes': {'USD': {'price': 22987.001734311547,
#     'volume_24h': 44226832.2892144}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 50)},
#  {'exchange_id': 'ftx',
#   'exchange_name': 'FTX (Spot)',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://ftx.com/trade/BTC/USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.14177570897046218,
#   'quotes': {'USD': {'price': 22983.59274469503,
#     'volume_24h': 44044606.67828444}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 46)},
#  {'exchange_id': 'cointiger',
#   'exchange_name': 'CoinTiger',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.cointiger.com/en-us/#/trade_pro?coin=btc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1405657247122621,
#   'quotes': {'USD': {'price': 22983.13227201809,
#     'volume_24h': 43668708.14724312}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 16)},
#  {'exchange_id': 'binance-us',
#   'exchange_name': 'Binance US',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.us/en/trade/pro/BTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.12573233659775232,
#   'quotes': {'USD': {'price': 22973.041914227735,
#     'volume_24h': 39060508.689421766}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 52)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BTC/BUSD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'busd-binance-usd',
#   'quote_currency_name': 'binance usd',
#   'market_url': 'https://hitbtc.com/BTC-to-BUSD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.12415549801612191,
#   'quotes': {'USD': {'price': 22970.663617010858,
#     'volume_24h': 38570641.73246988}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 56)},
#  {'exchange_id': 'arthbit',
#   'exchange_name': 'ArthBit',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11621366359127008,
#   'quotes': {'USD': {'price': 22991.160513037794,
#     'volume_24h': 36103399.80445007}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 34)},
#  {'exchange_id': 'dexzbitz',
#   'exchange_name': 'Dexzbitz',
#   'pair': 'BTC/USDi',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdi-usdi0',
#   'quote_currency_name': 'usdi0',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11541625675475015,
#   'quotes': {'USD': {'price': 22954.96742307588,
#     'volume_24h': 35855674.21921309}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 10)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/BTC/ETH',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.09877650367381932,
#   'quotes': {'USD': {'price': 22989.29151562269,
#     'volume_24h': 30686302.223153733}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 38)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://hitbtc.com/ETH-to-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.09842267309995746,
#   'quotes': {'USD': {'price': 22986.40321240042,
#     'volume_24h': 30576379.807179466}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 56)},
#  {'exchange_id': 'bequant',
#   'exchange_name': 'Bequant',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://bequant.io/ETH-to-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.09841671209907205,
#   'quotes': {'USD': {'price': 22985.463188550082,
#     'volume_24h': 30574527.93889178}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 39)},
#  {'exchange_id': 'coinone',
#   'exchange_name': 'Coinone',
#   'pair': 'BTC/KRW',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'krw-south-korea-won',
#   'quote_currency_name': 'south korea won',
#   'market_url': 'https://coinone.co.kr/exchange/trade/btc/krw',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.09360354494027008,
#   'quotes': {'USD': {'price': 23432.5117, 'volume_24h': 29079250.250451963}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 20, 25)},
#  {'exchange_id': 'bitstamp',
#   'exchange_name': 'Bitstamp',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://www.bitstamp.net/markets/btc/usd/',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0933795370413266,
#   'quotes': {'USD': {'price': 22964.41, 'volume_24h': 29009659.063968454}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22)},
#  {'exchange_id': 'bequant',
#   'exchange_name': 'Bequant',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://bequant.io/BTC-to-USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08951324256793597,
#   'quotes': {'USD': {'price': 22973.392876196118,
#     'volume_24h': 27808540.616954423}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 39)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://hitbtc.com/BTC-to-USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08946277213135208,
#   'quotes': {'USD': {'price': 22959.83049675109,
#     'volume_24h': 27792861.2700172}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 56)},
#  {'exchange_id': 'bibox',
#   'exchange_name': 'Bibox',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bibox.com/exchange?coinPair=BTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08302556046951985,
#   'quotes': {'USD': {'price': 22977.886887611196,
#     'volume_24h': 25793051.444983378}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 48)},
#  {'exchange_id': 'alterdice',
#   'exchange_name': 'Alterdice',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08160265368419203,
#   'quotes': {'USD': {'price': 22987.643989673277,
#     'volume_24h': 25351005.553238392}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 48)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BNB/BTC',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/BNB_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07696482532132792,
#   'quotes': {'USD': {'price': 22975.133677428566,
#     'volume_24h': 23910199.313812003}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'p2pb2b',
#   'exchange_name': 'P2PB2B',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://p2pb2b.com/trade/ETH_BTC/',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07680798477867114,
#   'quotes': {'USD': {'price': 22999.571624094242,
#     'volume_24h': 23861474.605872322}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 49)},
#  {'exchange_id': 'liquid',
#   'exchange_name': 'Liquid',
#   'pair': 'BTC/JPY',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'jpy-japanese-yen',
#   'quote_currency_name': 'japanese yen',
#   'market_url': 'https://app.liquid.com/exchange/BTCJPY',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07532390945951656,
#   'quotes': {'USD': {'price': 22990.54053024,
#     'volume_24h': 23400425.853672247}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 42)},
#  {'exchange_id': 'gemini',
#   'exchange_name': 'Gemini',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://gemini.com',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07237080581154874,
#   'quotes': {'USD': {'price': 22976.66, 'volume_24h': 22483002.907248832}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 19, 47)},
#  {'exchange_id': 'ftx',
#   'exchange_name': 'FTX (Spot)',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://ftx.com/trade/ETH/BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07217632826615872,
#   'quotes': {'USD': {'price': 22982.01709212001,
#     'volume_24h': 22422585.738068983}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 46)},
#  {'exchange_id': 'poloniex',
#   'exchange_name': 'Poloniex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://poloniex.com/exchange/#usdt_btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06753031074191641,
#   'quotes': {'USD': {'price': 22950.198465341236,
#     'volume_24h': 20979235.42113773}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 57)},
#  {'exchange_id': 'bitfinex',
#   'exchange_name': 'Bitfinex',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.bitfinex.com/t/ETH:BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06731539620748246,
#   'quotes': {'USD': {'price': 22977.945764670905,
#     'volume_24h': 20912469.215506826}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 35)},
#  {'exchange_id': 'bitvast',
#   'exchange_name': 'Bitvast',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06533739868381763,
#   'quotes': {'USD': {'price': 22987.411436716728,
#     'volume_24h': 20297976.62313623}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 53)},
#  {'exchange_id': 'whitebit',
#   'exchange_name': 'WhiteBIT',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://whitebit.com/trade/BTC_USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06332930794298197,
#   'quotes': {'USD': {'price': 22972.064613058898,
#     'volume_24h': 19674135.15200778}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 42)},
#  {'exchange_id': 'okcoin-international',
#   'exchange_name': 'OKCoin',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://www.okcoin.com/spot/trade#product=btc_usd',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06279095158203772,
#   'quotes': {'USD': {'price': 22963.63, 'volume_24h': 19506887.219744}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 50)},
#  {'exchange_id': 'bitvast',
#   'exchange_name': 'Bitvast',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05943407145717715,
#   'quotes': {'USD': {'price': 22974.03537440729,
#     'volume_24h': 18464025.46409277}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 53)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BTC/TRY',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'try-turkish-lira',
#   'quote_currency_name': 'turkish lira',
#   'market_url': 'https://www.binance.com/en/trade/BTC_TRY',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.056760729952047846,
#   'quotes': {'USD': {'price': 23149.58854356,
#     'volume_24h': 17633514.539723597}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'binance-us',
#   'exchange_name': 'Binance US',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://www.binance.us/en/trade/pro/BTC_USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.056603797406672235,
#   'quotes': {'USD': {'price': 22977.916873915794,
#     'volume_24h': 17584761.249852687}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 52)},
#  {'exchange_id': 'dexzbitz',
#   'exchange_name': 'Dexzbitz',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05540180984365396,
#   'quotes': {'USD': {'price': 22981.16124875527,
#     'volume_24h': 17211347.004000746}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 10)},
#  {'exchange_id': 'whitebit',
#   'exchange_name': 'WhiteBIT',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://whitebit.com/trade/ETH_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05330732845052441,
#   'quotes': {'USD': {'price': 22994.620076319756,
#     'volume_24h': 16560667.068592373}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 42)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.okx.com/trade-spot/eth-btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05215770444703,
#   'quotes': {'USD': {'price': 22975.754108854686,
#     'volume_24h': 16203520.29479366}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 27)},
#  {'exchange_id': 'bitvavo',
#   'exchange_name': 'Bitvavo',
#   'pair': 'BTC/EUR',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'eur-euro',
#   'quote_currency_name': 'euro',
#   'market_url': 'https://account.bitvavo.com/markets/BTC-EUR',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.049323156919780134,
#   'quotes': {'USD': {'price': 22963.633102779997,
#     'volume_24h': 15322928.465239594}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 7)},
#  {'exchange_id': 'bitfinex',
#   'exchange_name': 'Bitfinex',
#   'pair': 'BTC/GBP',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'gbp-pound-sterling',
#   'quote_currency_name': 'pound sterling',
#   'market_url': 'https://www.bitfinex.com/t/BTC:GBP',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04914217123353965,
#   'quotes': {'USD': {'price': 22965.77779297,
#     'volume_24h': 15266702.730783755}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 35)},
#  {'exchange_id': 'bitfinex',
#   'exchange_name': 'Bitfinex',
#   'pair': 'BTC/EUR',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'eur-euro',
#   'quote_currency_name': 'euro',
#   'market_url': 'https://www.bitfinex.com/t/BTC:EUR',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04423696596022727,
#   'quotes': {'USD': {'price': 22955.463535259998,
#     'volume_24h': 13742832.114948552}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 35)},
#  {'exchange_id': 'huobi',
#   'exchange_name': 'Huobi',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.hbg.com/en-us/exchange/?s=eth_btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04073777838684901,
#   'quotes': {'USD': {'price': 22977.319534630307,
#     'volume_24h': 12655760.56029249}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 49)},
#  {'exchange_id': 'coinbase',
#   'exchange_name': 'Coinbase',
#   'pair': 'BTC/EUR',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'eur-euro',
#   'quote_currency_name': 'euro',
#   'market_url': 'https://pro.coinbase.com/trade/BTC-EUR',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.040452632432067134,
#   'quotes': {'USD': {'price': 22961.856221844395,
#     'volume_24h': 12567175.981767206}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 21)},
#  {'exchange_id': 'bitstamp',
#   'exchange_name': 'Bitstamp',
#   'pair': 'BTC/EUR',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'eur-euro',
#   'quote_currency_name': 'euro',
#   'market_url': 'https://www.bitstamp.net/markets/btc/eur/',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03851360681435038,
#   'quotes': {'USD': {'price': 22959.466623344797,
#     'volume_24h': 11964790.556988655}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'WBTC/BTC',
#   'base_currency_id': 'wbtc-wrapped-bitcoin',
#   'base_currency_name': 'wrapped bitcoin',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/WBTC_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03715932599240171,
#   'quotes': {'USD': {'price': 22974.394322980443,
#     'volume_24h': 11544064.280478902}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ETC/BTC',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/ETC_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.036545967404704595,
#   'quotes': {'USD': {'price': 22931.849118431972,
#     'volume_24h': 11353515.857592892}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 7)},
#  {'exchange_id': 'dsdaq-global',
#   'exchange_name': 'Dsdaq Global',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.dsdaq.io/en_US/trade/BTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03628079924845854,
#   'quotes': {'USD': {'price': 22975.374308439197,
#     'volume_24h': 11271137.661565699}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 4)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://www.kucoin.com/trade/BTC-USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03502191862604483,
#   'quotes': {'USD': {'price': 22971.57442368798,
#     'volume_24h': 10880048.79118186}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 3)},
#  {'exchange_id': 'dex-trade',
#   'exchange_name': 'Dex-Trade',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03432565168734022,
#   'quotes': {'USD': {'price': 22978.57202884732,
#     'volume_24h': 10663743.729609381}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 28)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BTC/GBP',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'gbp-pound-sterling',
#   'quote_currency_name': 'pound sterling',
#   'market_url': 'https://www.binance.com/en/trade/BTC_GBP',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03428015436352448,
#   'quotes': {'USD': {'price': 22986.372465634497,
#     'volume_24h': 10649609.349700928}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'coinbase',
#   'exchange_name': 'Coinbase',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://pro.coinbase.com/trade/ETH-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03170891001275684,
#   'quotes': {'USD': {'price': 22975.754108854686,
#     'volume_24h': 9850816.334129296}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 21)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'LTC/BTC',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.bitrue.com/trade/ltc_btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.028123650313104678,
#   'quotes': {'USD': {'price': 22957.413696868785,
#     'volume_24h': 8737005.269755898}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 2)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BNB/BTC',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://hitbtc.com/BNB-to-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.02769273894033744,
#   'quotes': {'USD': {'price': 22971.846584835755,
#     'volume_24h': 8603136.625652084}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 56)},
#  {'exchange_id': 'coinbase',
#   'exchange_name': 'Coinbase',
#   'pair': 'BTC/GBP',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'gbp-pound-sterling',
#   'quote_currency_name': 'pound sterling',
#   'market_url': 'https://pro.coinbase.com/trade/BTC-GBP',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.027638743384166452,
#   'quotes': {'USD': {'price': 22955.848865738197,
#     'volume_24h': 8586362.151017493}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 21)},
#  {'exchange_id': 'cryptocom-exchange',
#   'exchange_name': 'Crypto.com Exchange',
#   'pair': 'BTC/USDC',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://crypto.com/exchange/trade/spot/BTC_USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.026023993262324893,
#   'quotes': {'USD': {'price': 22974.485548319357,
#     'volume_24h': 8084717.443918612}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 25)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'XRP/BTC',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/XRP_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.02581677696883529,
#   'quotes': {'USD': {'price': 22940.971186024184,
#     'volume_24h': 8020342.804494428}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'whitebit',
#   'exchange_name': 'WhiteBIT',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://whitebit.com/trade/BTC_USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.025360765488044265,
#   'quotes': {'USD': {'price': 22958.97, 'volume_24h': 7878676.46081628}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 42)},
#  {'exchange_id': 'ascendex',
#   'exchange_name': 'AscendEX (BitMax)',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://ascendex.com/en/cashtrade-spottrading/btc/usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.025272923701249467,
#   'quotes': {'USD': {'price': 22983.10224119133,
#     'volume_24h': 7851387.18131001}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 48)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'LINK/BTC',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/LINK_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.024757477607643807,
#   'quotes': {'USD': {'price': 22978.258391722047,
#     'volume_24h': 7691256.643987503}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'SOL/BTC',
#   'base_currency_id': 'sol-solana',
#   'base_currency_name': 'solana',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/SOL_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.024320186855974542,
#   'quotes': {'USD': {'price': 22977.453825457753,
#     'volume_24h': 7555406.156614261}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BTC/AUD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'aud-australian-dollar',
#   'quote_currency_name': 'australian dollar',
#   'market_url': 'https://www.binance.com/en/trade/BTC_AUD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.02431951134095546,
#   'quotes': {'USD': {'price': 22969.811181282003,
#     'volume_24h': 7555196.298426728}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 7)},
#  {'exchange_id': 'bitfinex',
#   'exchange_name': 'Bitfinex',
#   'pair': 'BTC/JPY',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'jpy-japanese-yen',
#   'quote_currency_name': 'japanese yen',
#   'market_url': 'https://www.bitfinex.com/t/BTC:JPY',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.023463778815883286,
#   'quotes': {'USD': {'price': 22958.005824000888,
#     'volume_24h': 7289351.022375443}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 35)},
#  {'exchange_id': 'polyx',
#   'exchange_name': 'Polyx',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.02251676050912074,
#   'quotes': {'USD': {'price': 22985.04423465495,
#     'volume_24h': 6995146.541640444}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 34)},
#  {'exchange_id': 'bitfinex',
#   'exchange_name': 'Bitfinex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitfinex.com/t/BTC:UST',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.022345762697499053,
#   'quotes': {'USD': {'price': 22986.59582737073,
#     'volume_24h': 6942023.680112073}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 35)},
#  {'exchange_id': 'bibox',
#   'exchange_name': 'Bibox',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.bibox.com/exchange?coinPair=ETH_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.022176845836636296,
#   'quotes': {'USD': {'price': 23001.535636603247,
#     'volume_24h': 6889547.295038374}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 48)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'NEAR/BTC',
#   'base_currency_id': 'near-near-protocol',
#   'base_currency_name': 'near protocol',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/NEAR_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.021919481551912683,
#   'quotes': {'USD': {'price': 22965.04697250425,
#     'volume_24h': 6809593.480834199}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'dexzbitz',
#   'exchange_name': 'Dexzbitz',
#   'pair': 'BTC/USD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.02162292438062593,
#   'quotes': {'USD': {'price': 22959.61, 'volume_24h': 6717463.84831957}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 10)},
#  {'exchange_id': 'bitkub',
#   'exchange_name': 'Bitkub',
#   'pair': 'BTC/THB',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'thb-thai-baht',
#   'quote_currency_name': 'thai baht',
#   'market_url': 'https://www.bitkub.com/market',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.021470913718977438,
#   'quotes': {'USD': {'price': 23046.194216400003,
#     'volume_24h': 6670239.6104594115}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 26)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'AVAX/BTC',
#   'base_currency_id': 'avax-avalanche',
#   'base_currency_name': 'avalanche',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/AVAX_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.021224533343250432,
#   'quotes': {'USD': {'price': 22991.94430315333,
#     'volume_24h': 6593698.101191384}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'DOT/BTC',
#   'base_currency_id': 'dot-polkadot',
#   'base_currency_name': 'polkadot',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/DOT_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.019607848224772614,
#   'quotes': {'USD': {'price': 22992.037126713083,
#     'volume_24h': 6091452.26032716}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'luno',
#   'exchange_name': 'Luno',
#   'pair': 'BTC/ZAR',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'zar-south-african-rand',
#   'quote_currency_name': 'south african rand',
#   'market_url': 'https://www.luno.com/trade/XBTZAR',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.01930928423447949,
#   'quotes': {'USD': {'price': 23381.78086422,
#     'volume_24h': 5998699.181423499}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 11)},
#  {'exchange_id': 'coinex',
#   'exchange_name': 'CoinEx',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.coinex.com/exchange?currency=usdt&dest=btc#limit',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.01915452575644172,
#   'quotes': {'USD': {'price': 22977.896897886785,
#     'volume_24h': 5950621.295974705}},
#   'trust_score': 'high',
# ...
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 54)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BTCA/BTC',
#   'base_currency_id': 'btca-bitair',
#   'base_currency_name': 'bitair',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://hitbtc.com/BTCA-to-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00016331513283101716,
#   'quotes': {'USD': {'price': 22953.61962051555,
#     'volume_24h': 50736.129922316686}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 56)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'XEM/BTC',
#   'base_currency_id': 'xem-nem',
#   'base_currency_name': 'nem',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.okx.com/trade-spot/xem-btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00016310551655734505,
#   'quotes': {'USD': {'price': 23126.320733940604,
#     'volume_24h': 50671.009695485875}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 27)},
#  {'exchange_id': 'bitmart',
#   'exchange_name': 'BitMart',
#   'pair': 'LOOM/BTC',
#   'base_currency_id': 'loom-loom-network',
#   'base_currency_name': 'loom network',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.bitmart.com/trade/en?layout=basic&symbol=LOOM_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00016130032945810884,
#   'quotes': {'USD': {'price': 23310.220980461407,
#     'volume_24h': 50110.20307816092}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 51)},
#  {'exchange_id': 'tidebit',
#   'exchange_name': 'Tidebit',
#   'pair': 'BTC/HKD',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'hkd-hong-kong-dollar',
#   'quote_currency_name': 'hong kong dollar',
#   'market_url': 'https://www.tidebit.com/markets/btchkd',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00016085502069544124,
#   'quotes': {'USD': {'price': 22676.3450939519,
#     'volume_24h': 49971.8616835418}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 52)},
#  {'exchange_id': 'upbit',
#   'exchange_name': 'Upbit',
#   'pair': 'ETH/BTC',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://upbit.com/exchange?code=CRIX.UPBIT.BTC-ETH',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00016073120739767353,
#   'quotes': {'USD': {'price': 22844.39339951378,
#     'volume_24h': 49933.39735110206}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 5)},
#  {'exchange_id': 'bittrex',
#   'exchange_name': 'Bittrex',
#   'pair': 'LTC/BTC',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://bittrex.com/Market/Index?MarketName=BTC-LTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0001606022994499,
#   'quotes': {'USD': {'price': 22967.314677376547,
#     'volume_24h': 49893.350294391}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 42)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'JOE/BTC',
#   'base_currency_id': 'joe-trader-joe',
#   'base_currency_name': 'trader joe',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/JOE_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00015810476356204319,
#   'quotes': {'USD': {'price': 23084.494761541646,
#     'volume_24h': 49117.455843611206}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'cryptology',
#   'exchange_name': 'Cryptology',
#   'pair': 'DYDX/BTC',
#   'base_currency_id': 'dydx-dydx',
#   'base_currency_name': 'dydx',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://cryptology.com',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00015709827637342205,
#   'quotes': {'USD': {'price': 22966.97071608092,
#     'volume_24h': 48804.776523074106}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 34)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'ANT/BTC',
#   'base_currency_id': 'ant-aragon',
#   'base_currency_name': 'aragon',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.okx.com/trade-spot/ant-btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0001566493089837871,
#   'quotes': {'USD': {'price': 22980.68236416912,
#     'volume_24h': 48665.29852482288}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 27)},
#  {'exchange_id': 'cryptocom-exchange',
#   'exchange_name': 'Crypto.com Exchange',
#   'pair': 'LTC/BTC',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://crypto.com/exchange/trade/spot/LTC_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00015605362042643987,
#   'quotes': {'USD': {'price': 22943.834578940212,
#     'volume_24h': 48480.239543974625}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 25)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'OCEAN/BTC',
#   'base_currency_id': 'ocean-ocean-protocol',
#   'base_currency_name': 'ocean protocol',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.kucoin.com/trade/OCEAN-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.000155116615760517,
#   'quotes': {'USD': {'price': 22937.373795396317,
#     'volume_24h': 48189.14594080394}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 3)},
#  {'exchange_id': 'binance-us',
#   'exchange_name': 'Binance US',
#   'pair': 'SOL/BTC',
#   'base_currency_id': 'sol-solana',
#   'base_currency_name': 'solana',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.us/en/trade/pro/SOL_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00015486107611498653,
#   'quotes': {'USD': {'price': 22964.114229622945,
#     'volume_24h': 48109.758976282086}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 52)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'VET/BTC',
#   'base_currency_id': 'vet-vechain',
#   'base_currency_name': 'vechain',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.kucoin.com/trade/VET-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00015457253752371267,
#   'quotes': {'USD': {'price': 22966.998328014175,
#     'volume_24h': 48020.12042778567}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 3)},
#  {'exchange_id': 'upbit',
#   'exchange_name': 'Upbit',
#   'pair': 'FLOW/BTC',
#   'base_currency_id': 'flow-flow',
#   'base_currency_name': 'flow',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://upbit.com/exchange?code=CRIX.UPBIT.BTC-FLOW',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00015357801992879798,
#   'quotes': {'USD': {'price': 22880.68344730966,
#     'volume_24h': 47711.1596289243}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 5)},
#  {'exchange_id': 'coinbase',
#   'exchange_name': 'Coinbase',
#   'pair': 'SNX/BTC',
#   'base_currency_id': 'snx-synthetix-network-token',
#   'base_currency_name': 'synthetix network token',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://pro.coinbase.com/trade/SNX-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00015220486199604108,
#   'quotes': {'USD': {'price': 22916.664181895816,
#     'volume_24h': 47284.56891395179}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 21, 21)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'DODO/BTC',
#   'base_currency_id': 'dodo-dodo',
#   'base_currency_name': 'dodo',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/DODO_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0001511149026299049,
#   'quotes': {'USD': {'price': 22976.371089180393,
#     'volume_24h': 46945.95779413871}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 7)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'BSV/BTC',
#   'base_currency_id': 'bsv-bitcoin-sv',
#   'base_currency_name': 'bitcoin sv',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.kucoin.com/trade/BCHSV-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0001510256267261004,
#   'quotes': {'USD': {'price': 22956.080195115555,
#     'volume_24h': 46918.22298612774}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 3)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'WXT/BTC',
#   'base_currency_id': 'wxt-wirex-token',
#   'base_currency_name': 'wirex token',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.okex.com/market?product=wxt_btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00014936053329776117,
#   'quotes': {'USD': {'price': 22923.262574088763,
#     'volume_24h': 46400.93842683079}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 27)},
#  {'exchange_id': 'bitforex',
#   'exchange_name': 'BitForex',
#   'pair': 'BCH/BTC',
#   'base_currency_id': 'bch-bitcoin-cash',
#   'base_currency_name': 'bitcoin cash',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.bitforex.com/en/spot/bch_btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0001489472483987763,
#   'quotes': {'USD': {'price': 22987.352151779036,
#     'volume_24h': 46272.5456933079}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 20)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'SFP/BTC',
#   'base_currency_id': 'sfp-safepal-token',
#   'base_currency_name': 'safepal token',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/SFP_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00014857408859686054,
#   'quotes': {'USD': {'price': 23092.53972634184,
#     'volume_24h': 46156.618382325796}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'NEO/BTC',
#   'base_currency_id': 'neo-neo',
#   'base_currency_name': 'neo',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.okx.com/trade-spot/neo-btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00014827216529874428,
#   'quotes': {'USD': {'price': 23007.483494407985,
#     'volume_24h': 46062.82168746806}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 27)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'CVC/BTC',
#   'base_currency_id': 'cvc-civic',
#   'base_currency_name': 'civic',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/CVC_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00014760148854319017,
#   'quotes': {'USD': {'price': 23201.005205219084,
#     'volume_24h': 45854.466574161575}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 6)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'REP/BTC',
#   'base_currency_id': 'rep-augur',
#   'base_currency_name': 'augur',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.binance.com/en/trade/REP_BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00014704647458733987,
#   'quotes': {'USD': {'price': 23340.13123362922,
#     'volume_24h': 45682.04372708924}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 23, 7)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'BNT/BTC',
#   'base_currency_id': 'bnt-bancor',
#   'base_currency_name': 'bancor',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.okx.com/trade-spot/bnt-btc',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00014687407194545067,
#   'quotes': {'USD': {'price': 22949.38736242555,
#     'volume_24h': 45628.48443539218}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 27)},
#  {'exchange_id': 'probit-exchange',
#   'exchange_name': 'ProBit Exchange',
#   'pair': 'OMG/BTC',
#   'base_currency_id': 'omg-omg-network',
#   'base_currency_name': 'omg network',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.probit.com/app/exchange/OMG-BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00014669987972196005,
#   'quotes': {'USD': {'price': 23051.316211254623,
#     'volume_24h': 45574.36918514393}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 19, 21)},
#  {'exchange_id': 'catex',
#   'exchange_name': 'Catex',
#   'pair': 'LINK/BTC',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'btc-bitcoin',
#   'quote_currency_name': 'bitcoin',
#   'market_url': 'https://www.catex.io/trading/LINK/BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0001463067993854945,
#   'quotes': {'USD': {'price': 22968.816565235924,
#     'volume_24h': 45452.25328152182}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 35)},
#  {'exchange_id': 'luno',
#   'exchange_name': 'Luno',
#   'pair': 'BTC/EUR',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'eur-euro',
#   'quote_currency_name': 'euro',
#   'market_url': 'https://www.luno.com/trade/XBTEUR',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00014614929301687068,
#   'quotes': {'USD': {'price': 22622.4821751042,
#     'volume_24h': 45403.32172543413}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 10, 7, 22, 11)},
#  ...]

# %%
api_client = Coinpaprika.Client()
btc_ticker = api_client.tickers.for_coin("btc-bitcoin")

# %%
btc_ticker
# Out:
# {'id': 'btc-bitcoin',
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'rank': 1,
#  'circulating_supply': 19117519,
#  'total_supply': 19117506,
#  'max_supply': 21000000,
#  'beta_value': 0.95082,
#  'first_data_at': datetime.datetime(2010, 7, 17, 0, 0),
#  'last_updated': datetime.datetime(2022, 8, 10, 7, 32, 30),
#  'quotes': {'USD': {'price': 22986.574830129564,
#    'volume_24h': 31470763276.060303,
#    'volume_24h_change_24h': -5.08,
#    'market_cap': 439446281060,
#    'market_cap_change_24h': -3.6,
#    'percent_change_15m': 0.07,
#    'percent_change_30m': 0.1,
#    'percent_change_1h': 0.29,
#    'percent_change_6h': 0.39,
#    'percent_change_12h': -0.57,
#    'percent_change_24h': -3.6,
#    'percent_change_7d': -0.93,
#    'percent_change_30d': 15.45,
#    'percent_change_1y': -50.17,
#    'ath_price': 68692.137036932,
#    'ath_date': '2021-11-10T16:51:15Z',
#    'percent_from_price_ath': -66.54}}}
