# %%
import coinpaprika as Coinpaprika

# %%
api_client = Coinpaprika.Client()
markets = api_client.coins.markets("usdt-tether")

# %%
markets
# Out:
# [{'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ETH_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 2.501371761510243,
#   'quotes': {'USD': {'price': 0.9990167404331869,
#     'volume_24h': 1347545589.603983}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'xt',
#   'exchange_name': 'XT',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 1.145626317428537,
#   'quotes': {'USD': {'price': 0.9999589143595193,
#     'volume_24h': 617174829.8833411}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 58)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BUSD/USDT',
#   'base_currency_id': 'busd-binance-usd',
#   'base_currency_name': 'binance usd',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/BUSD_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.8430219217261656,
#   'quotes': {'USD': {'price': 0.9986061282081522,
#     'volume_24h': 454154992.0894941}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/BTC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.8406909126128355,
#   'quotes': {'USD': {'price': 0.9964949596422453,
#     'volume_24h': 452899224.7148364}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 47, 6)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/BTC-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.7091178784067111,
#   'quotes': {'USD': {'price': 0.9985595420761607,
#     'volume_24h': 382017852.8678029}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/ETH-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.6845411014240438,
#   'quotes': {'USD': {'price': 0.9997663044764687,
#     'volume_24h': 368777786.78115356}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/ETH',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.6626489439253355,
#   'quotes': {'USD': {'price': 0.9990570109846981,
#     'volume_24h': 356983985.9802328}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 47, 6)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ETC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.36208976911880997,
#   'quotes': {'USD': {'price': 0.9987784413559802,
#     'volume_24h': 195065954.97911105}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'SOL/USDT',
#   'base_currency_id': 'sol-solana',
#   'base_currency_name': 'solana',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/SOL_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.3297333464829774,
#   'quotes': {'USD': {'price': 0.9992411161848023,
#     'volume_24h': 177634817.6770919}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'USDC/USDT',
#   'base_currency_id': 'usdc-usd-coin',
#   'base_currency_name': 'usd coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/USDC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.32717715659457514,
#   'quotes': {'USD': {'price': 0.9983809896560591,
#     'volume_24h': 176257740.3216543}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'USDC/USDT',
#   'base_currency_id': 'usdc-usd-coin',
#   'base_currency_name': 'usd coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.30348098164940845,
#   'quotes': {'USD': {'price': 0.9982811315854794,
#     'volume_24h': 163492074.4861351}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 47, 6)},
#  {'exchange_id': 'p2pb2b',
#   'exchange_name': 'P2PB2B',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://p2pb2b.com/trade/BTC_USDT/',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.2607164561097651,
#   'quotes': {'USD': {'price': 0.9913562015265581,
#     'volume_24h': 140453856.54940587}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 12)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/BNB_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.2592611810187706,
#   'quotes': {'USD': {'price': 0.9978503076719868,
#     'volume_24h': 139669866.91591525}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BUSD/USDT',
#   'base_currency_id': 'busd-binance-usd',
#   'base_currency_name': 'binance usd',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/BUSD-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.2267113927881566,
#   'quotes': {'USD': {'price': 0.9984163721706286,
#     'volume_24h': 122134559.19091521}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ADA/USDT',
#   'base_currency_id': 'ada-cardano',
#   'base_currency_name': 'cardano',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ADA_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.19896170062380408,
#   'quotes': {'USD': {'price': 0.9976034424585892,
#     'volume_24h': 107185171.87298842}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'CHZ/USDT',
#   'base_currency_id': 'chz-chiliz',
#   'base_currency_name': 'chiliz',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/CHZ_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1721728697081935,
#   'quotes': {'USD': {'price': 0.9991786209981619,
#     'volume_24h': 92753422.26005508}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'btcex',
#   'exchange_name': 'BTCEX',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.17096620968046816,
#   'quotes': {'USD': {'price': 0.9989739565292498,
#     'volume_24h': 92103367.18886046}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 42)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'SHIB/USDT',
#   'base_currency_id': 'shib-shiba-inu',
#   'base_currency_name': 'shiba inu',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/SHIB-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.16144777618664885,
#   'quotes': {'USD': {'price': 0.999577348361528,
#     'volume_24h': 86975571.60409269}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'SAND/USDT',
#   'base_currency_id': 'sand-the-sandbox',
#   'base_currency_name': 'the sandbox',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/SAND_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.156258736771558,
#   'quotes': {'USD': {'price': 1.0075078299198648,
#     'volume_24h': 84180118.61078589}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/BNB-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.14827897078558475,
#   'quotes': {'USD': {'price': 0.9992271608411644,
#     'volume_24h': 79881238.0421583}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'MATIC/USDT',
#   'base_currency_id': 'matic-polygon',
#   'base_currency_name': 'polygon',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/MATIC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1470636743559825,
#   'quotes': {'USD': {'price': 0.9989140176367917,
#     'volume_24h': 79226530.34577686}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'lbank',
#   'exchange_name': 'Lbank',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.lbank.info/exchange.html?asset=eth&post=usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.14374968620359327,
#   'quotes': {'USD': {'price': 1.0002161793918922,
#     'volume_24h': 77441209.91181797}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 51)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'XRP/USDT',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/XRP_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1361080441282701,
#   'quotes': {'USD': {'price': 0.9984560164379904,
#     'volume_24h': 73324484.34771521}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'cryptocom-exchange',
#   'exchange_name': 'Crypto.com Exchange',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://crypto.com/exchange/trade/spot/ETH_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.13511410973469865,
#   'quotes': {'USD': {'price': 0.9986041543836807,
#     'volume_24h': 72789029.39095011}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 2)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'OP/USDT',
#   'base_currency_id': 'op-optimism',
#   'base_currency_name': 'optimism',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/OP_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.13442767909692457,
#   'quotes': {'USD': {'price': 0.9989258207287047,
#     'volume_24h': 72419233.66816518}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'GALA/USDT',
#   'base_currency_id': 'gala-gala',
#   'base_currency_name': 'gala',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/GALA_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.13275271996465443,
#   'quotes': {'USD': {'price': 0.9992290157672273,
#     'volume_24h': 71516895.26881634}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/ETC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.13181142280662006,
#   'quotes': {'USD': {'price': 0.9992677074286311,
#     'volume_24h': 71009797.18234472}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 47, 6)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'AVAX/USDT',
#   'base_currency_id': 'avax-avalanche',
#   'base_currency_name': 'avalanche',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/AVAX_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.12892783118271361,
#   'quotes': {'USD': {'price': 0.9991459866384338,
#     'volume_24h': 69456341.10084325}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'USDT/TRY',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'try-turkish-lira',
#   'quote_currency_name': 'turkish lira',
#   'market_url': 'https://www.binance.com/en/trade/USDT_TRY',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.12343861019498213,
#   'quotes': {'USD': {'price': 1.0030933899, 'volume_24h': 66499173.49936959}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'APE/USDT',
#   'base_currency_id': 'ape-apecoin',
#   'base_currency_name': 'apecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/APE_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.12218815465600028,
#   'quotes': {'USD': {'price': 0.9985816618253908,
#     'volume_24h': 65825524.79489493}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'btcex',
#   'exchange_name': 'BTCEX',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1198285711642085,
#   'quotes': {'USD': {'price': 0.9981577168856873,
#     'volume_24h': 64554363.755743116}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 42)},
#  {'exchange_id': 'bitforex',
#   'exchange_name': 'BitForex',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitforex.com/en/spot/eth_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.1131735525986747,
#   'quotes': {'USD': {'price': 0.9987299066975318,
#     'volume_24h': 60969154.60982106}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 27)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'DOT/USDT',
#   'base_currency_id': 'dot-polkadot',
#   'base_currency_name': 'polkadot',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/DOT_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11277546043890875,
#   'quotes': {'USD': {'price': 0.998009225213825,
#     'volume_24h': 60754693.3520412}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.okx.com/trade-spot/etc-usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.11179850602901678,
#   'quotes': {'USD': {'price': 1.0000375233392005,
#     'volume_24h': 60228385.8968474}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 59)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'DOGE/USDT',
#   'base_currency_id': 'doge-dogecoin',
#   'base_currency_name': 'dogecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/DOGE',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.10300438061912301,
#   'quotes': {'USD': {'price': 0.9990057482562642,
#     'volume_24h': 55490791.472509705}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 47, 6)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'WAVES/USDT',
#   'base_currency_id': 'waves-waves',
#   'base_currency_name': 'waves',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/WAVES_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.09652060014699532,
#   'quotes': {'USD': {'price': 1.0055470211852615,
#     'volume_24h': 51997832.16369394}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'NEAR/USDT',
#   'base_currency_id': 'near-near-protocol',
#   'base_currency_name': 'near protocol',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/NEAR_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08837133422124277,
#   'quotes': {'USD': {'price': 0.9983715759523629,
#     'volume_24h': 47607638.14066411}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'bequant',
#   'exchange_name': 'Bequant',
#   'pair': 'USDT/USDC',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://bequant.io/USD-to-USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08828931188306677,
#   'quotes': {'USD': {'price': 0.9979312441354913,
#     'volume_24h': 47563450.850410484}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 3)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'USDT/USDC',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'usdc-usd-coin',
#   'quote_currency_name': 'usd coin',
#   'market_url': 'https://hitbtc.com/USDT-to-USDC',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08828931188306677,
#   'quotes': {'USD': {'price': 0.9979312441354913,
#     'volume_24h': 47563450.850410484}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'XRP/USDT',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitrue.com/trade/xrp_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08611126531279258,
#   'quotes': {'USD': {'price': 0.9992409661364481,
#     'volume_24h': 46390087.860195465}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 51)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'FIL/USDT',
#   'base_currency_id': 'fil-filecoin',
#   'base_currency_name': 'filecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/FIL_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08559711783890427,
#   'quotes': {'USD': {'price': 0.9982317585387145,
#     'volume_24h': 46113104.97764069}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'whitebit',
#   'exchange_name': 'WhiteBIT',
#   'pair': 'USDC/USDT',
#   'base_currency_id': 'usdc-usd-coin',
#   'base_currency_name': 'usd coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://whitebit.com/trade/USDC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08518237420022845,
#   'quotes': {'USD': {'price': 0.9983809896560591,
#     'volume_24h': 45889673.19124503}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 58)},
#  {'exchange_id': 'ftx',
#   'exchange_name': 'FTX (Spot)',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://ftx.com/trade/ETH/USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08440957381547642,
#   'quotes': {'USD': {'price': 0.998709784199034,
#     'volume_24h': 45473348.130675815}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 15)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'LINK/USDT',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/LINK_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08351284305681193,
#   'quotes': {'USD': {'price': 0.9996691310559108,
#     'volume_24h': 44990258.972360946}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'cointiger',
#   'exchange_name': 'CoinTiger',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.cointiger.com/en-us/#/trade_pro?coin=btc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08273616950968901,
#   'quotes': {'USD': {'price': 0.9976198536146237,
#     'volume_24h': 44571847.35154867}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 5)},
#  {'exchange_id': 'ftx',
#   'exchange_name': 'FTX (Spot)',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://ftx.com/trade/BTC/USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.08033028348645224,
#   'quotes': {'USD': {'price': 0.9970584919606604,
#     'volume_24h': 43275742.09059172}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 15)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'TRX/USDT',
#   'base_currency_id': 'trx-tron',
#   'base_currency_name': 'tron',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/TRX_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07696047677549925,
#   'quotes': {'USD': {'price': 0.9985004980328803,
#     'volume_24h': 41460350.93561165}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'kraken',
#   'exchange_name': 'Kraken',
#   'pair': 'USDT/USD',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://trade.kraken.com/charts/KRAKEN:USDT-ZUSD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07664603016626283,
#   'quotes': {'USD': {'price': 1.0003, 'volume_24h': 41290951.429323696}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 41)},
#  {'exchange_id': 'binance-us',
#   'exchange_name': 'Binance US',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.us/en/trade/pro/BTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07446733964688869,
#   'quotes': {'USD': {'price': 0.9985052811642766,
#     'volume_24h': 40117241.52915194}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 44)},
#  {'exchange_id': 'bitforex',
#   'exchange_name': 'BitForex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitforex.com/en/spot/btc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07307996778714775,
#   'quotes': {'USD': {'price': 0.9973811976938369,
#     'volume_24h': 39369832.90341219}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 27)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'FIL/USDT',
#   'base_currency_id': 'fil-filecoin',
#   'base_currency_name': 'filecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/FIL-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07233911554514666,
#   'quotes': {'USD': {'price': 0.9984813788834354,
#     'volume_24h': 38970719.03052909}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'FTM/USDT',
#   'base_currency_id': 'ftm-fantom',
#   'base_currency_name': 'fantom',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/FTM_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.07074629243035462,
#   'quotes': {'USD': {'price': 0.9971740513463899,
#     'volume_24h': 38112629.16304719}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'resfinex',
#   'exchange_name': 'Resfinex',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://trade.resfinex.com/?pair=ETH_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06989188289755395,
#   'quotes': {'USD': {'price': 0.9991879127020648,
#     'volume_24h': 37652339.40709904}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 8)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitrue.com/trade/etc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06916438959167037,
#   'quotes': {'USD': {'price': 1.000177617318655,
#     'volume_24h': 37260422.29549866}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 51)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'CHZ/USDT',
#   'base_currency_id': 'chz-chiliz',
#   'base_currency_name': 'chiliz',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/CHZ-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06636432794484753,
#   'quotes': {'USD': {'price': 0.998858295554802,
#     'volume_24h': 35751965.703457646}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'RUNE/USDT',
#   'base_currency_id': 'rune-thorchain',
#   'base_currency_name': 'thorchain',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/RUNE_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06625331571616858,
#   'quotes': {'USD': {'price': 0.9982679490280708,
#     'volume_24h': 35692160.90296765}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'ftx',
#   'exchange_name': 'FTX (Spot)',
#   'pair': 'USDT/USD',
#   'base_currency_id': 'usdt-tether',
#   'base_currency_name': 'tether',
#   'quote_currency_id': 'usd-us-dollars',
#   'quote_currency_name': 'us dollars',
#   'market_url': 'https://ftx.com/trade/USDT/USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06505206475637704,
#   'quotes': {'USD': {'price': 1.0004, 'volume_24h': 35045019.81911}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 15)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'MANA/USDT',
#   'base_currency_id': 'mana-decentraland',
#   'base_currency_name': 'decentraland',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/MANA_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06164293566817919,
#   'quotes': {'USD': {'price': 0.9991181453155671,
#     'volume_24h': 33208444.809396937}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'okx',
#   'exchange_name': 'OKX',
#   'pair': 'OP/USDT',
#   'base_currency_id': 'op-optimism',
#   'base_currency_name': 'optimism',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.okx.com/trade-spot/op-usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.06145063585104813,
#   'quotes': {'USD': {'price': 0.9991910340091319,
#     'volume_24h': 33104848.544961557}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 59)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'LTC/USDT',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/LTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05857825327775718,
#   'quotes': {'USD': {'price': 0.9977719492782808,
#     'volume_24h': 31557431.03275754}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'dsdaq-global',
#   'exchange_name': 'Dsdaq Global',
#   'pair': 'LTC/USDT',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.dsdaq.io/en_US/trade/LTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05847190580292082,
#   'quotes': {'USD': {'price': 0.9994714679283366,
#     'volume_24h': 31500139.24075509}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 49)},
#  {'exchange_id': 'alterdice',
#   'exchange_name': 'Alterdice',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05579856080263783,
#   'quotes': {'USD': {'price': 0.997694482092734,
#     'volume_24h': 30059947.77459487}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 10)},
#  {'exchange_id': 'p2pb2b',
#   'exchange_name': 'P2PB2B',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://p2pb2b.com/trade/BNB_USDT/',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.052810264316129736,
#   'quotes': {'USD': {'price': 0.9975430877496739,
#     'volume_24h': 28450084.81348437}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 12)},
#  {'exchange_id': 'bkex',
#   'exchange_name': 'Bkex',
#   'pair': 'BNB/USDT',
#   'base_currency_id': 'bnb-binance-coin',
#   'base_currency_name': 'binance coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bkex.com/trade/BNB_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.05011378863350714,
#   'quotes': {'USD': {'price': 1.027273287574807,
#     'volume_24h': 26997432.325155888}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 44, 20)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'UNI/USDT',
#   'base_currency_id': 'uni-uniswap',
#   'base_currency_name': 'uniswap',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/UNI_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04960694441653646,
#   'quotes': {'USD': {'price': 0.9964719666836513,
#     'volume_24h': 26724383.872420993}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'LRC/USDT',
#   'base_currency_id': 'lrc-loopring',
#   'base_currency_name': 'loopring',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/LRC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04875890185941397,
#   'quotes': {'USD': {'price': 0.9999467789361252,
#     'volume_24h': 26267524.150395136}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'AXS/USDT',
#   'base_currency_id': 'axs-axie-infinity',
#   'base_currency_name': 'axie infinity',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/AXS_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.047600223878494864,
#   'quotes': {'USD': {'price': 0.9994014301990929,
#     'volume_24h': 25643318.0939487}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'ADA/USDT',
#   'base_currency_id': 'ada-cardano',
#   'base_currency_name': 'cardano',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://hitbtc.com/ADA-to-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.044171753057533125,
#   'quotes': {'USD': {'price': 0.997865399474098,
#     'volume_24h': 23796323.254971415}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)},
#  {'exchange_id': 'bequant',
#   'exchange_name': 'Bequant',
#   'pair': 'ADA/USDT',
#   'base_currency_id': 'ada-cardano',
#   'base_currency_name': 'cardano',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://bequant.io/ADA-to-USD',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04415775073039408,
#   'quotes': {'USD': {'price': 0.9979577243906488,
#     'volume_24h': 23788779.884381425}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 3)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'FIL/USDT',
#   'base_currency_id': 'fil-filecoin',
#   'base_currency_name': 'filecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/fil_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04408800618459542,
#   'quotes': {'USD': {'price': 0.9994572835411519,
#     'volume_24h': 23751206.91880466}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)},
#  {'exchange_id': 'bibox',
#   'exchange_name': 'Bibox',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bibox.com/exchange?coinPair=BTC_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.043183800561469574,
#   'quotes': {'USD': {'price': 0.9991789360049151,
#     'volume_24h': 23264090.881801546}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 46, 51)},
#  {'exchange_id': 'deepcoin',
#   'exchange_name': 'Deepcoin',
#   'pair': 'XRP/USDT',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.04187569853706079,
#   'quotes': {'USD': {'price': 0.998979179139818,
#     'volume_24h': 22559386.710727103}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 59)},
#  {'exchange_id': 'dsdaq-global',
#   'exchange_name': 'Dsdaq Global',
#   'pair': 'LINK/USDT',
#   'base_currency_id': 'link-chainlink',
#   'base_currency_name': 'chainlink',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.dsdaq.io/en_US/trade/LINK_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.040626324577072624,
#   'quotes': {'USD': {'price': 1.0025488639315994,
#     'volume_24h': 21886320.677339237}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 49)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'UNFI/USDT',
#   'base_currency_id': 'unfi-unifi-protocol',
#   'base_currency_name': 'unifi protocol',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/UNFI_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.040590003361069125,
#   'quotes': {'USD': {'price': 0.9987844448338946,
#     'volume_24h': 21866753.616102003}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ZIL/USDT',
#   'base_currency_id': 'zil-zilliqa',
#   'base_currency_name': 'zilliqa',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ZIL_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03988572539984,
#   'quotes': {'USD': {'price': 0.99750222613263,
#     'volume_24h': 21487343.136175342}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'USDC/USDT',
#   'base_currency_id': 'usdc-usd-coin',
#   'base_currency_name': 'usd coin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.kucoin.com/trade/USDC-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.038759444259941433,
#   'quotes': {'USD': {'price': 0.9984309261833264,
#     'volume_24h': 20880589.991329685}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 35)},
#  {'exchange_id': 'bitfinex',
#   'exchange_name': 'Bitfinex',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitfinex.com/t/BTC:UST',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.038486554171694214,
#   'quotes': {'USD': {'price': 0.9986640611908708,
#     'volume_24h': 20733577.923582442}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 50)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'LRC/USDT',
#   'base_currency_id': 'lrc-loopring',
#   'base_currency_name': 'loopring',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitrue.com/trade/lrc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.037407875147514036,
#   'quotes': {'USD': {'price': 0.9999467789361252,
#     'volume_24h': 20152469.116007708}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 51)},
#  {'exchange_id': 'cointiger',
#   'exchange_name': 'CoinTiger',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.cointiger.com/en-us/#/trade_pro?coin=etc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03637197353801361,
#   'quotes': {'USD': {'price': 0.9994518887699567,
#     'volume_24h': 19594405.47004124}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 5)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ATOM/USDT',
#   'base_currency_id': 'atom-cosmos',
#   'base_currency_name': 'cosmos',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ATOM_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03634627610288534,
#   'quotes': {'USD': {'price': 0.9985144475663251,
#     'volume_24h': 19580561.680044062}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'bitrue',
#   'exchange_name': 'Bitrue',
#   'pair': 'LTC/USDT',
#   'base_currency_id': 'ltc-litecoin',
#   'base_currency_name': 'litecoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitrue.com/trade/ltc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0360037955222225,
#   'quotes': {'USD': {'price': 0.9983892869112447,
#     'volume_24h': 19396059.638764687}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 51)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'ETC/USDT',
#   'base_currency_id': 'etc-ethereum-classic',
#   'base_currency_name': 'ethereum classic',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/etc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.03579399216107944,
#   'quotes': {'USD': {'price': 0.9999441491540145,
#     'volume_24h': 19283033.81895543}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)},
#  {'exchange_id': 'hitbtc',
#   'exchange_name': 'HitBTC',
#   'pair': 'WAVES/USDT',
#   'base_currency_id': 'waves-waves',
#   'base_currency_name': 'waves',
# ...
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012361142129358618,
#   'quotes': {'USD': {'price': 0.9993542534728226,
#     'volume_24h': 665922.7074998296}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'tarmex',
#   'exchange_name': 'Tarmex',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001233608492708167,
#   'quotes': {'USD': {'price': 0.9991149055907634,
#     'volume_24h': 664572.819293059}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 51)},
#  {'exchange_id': 'kucoin',
#   'exchange_name': 'Kucoin',
#   'pair': 'AGIX/USDT',
#   'base_currency_id': 'agix-singularitynet',
#   'base_currency_name': 'singularity net',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.kucoin.com/trade/AGIX-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001233429366837002,
#   'quotes': {'USD': {'price': 0.9895075669743442,
#     'volume_24h': 664476.3201315243}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 35)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'FTM/USDT',
#   'base_currency_id': 'ftm-fantom',
#   'base_currency_name': 'fantom',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/ftm_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012307891125903764,
#   'quotes': {'USD': {'price': 0.9970740689880054,
#     'volume_24h': 663053.9554034099}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'GT/USDT',
#   'base_currency_id': 'gt-gatechain-token',
#   'base_currency_name': 'gatechain token',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/gt_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012292085374542509,
#   'quotes': {'USD': {'price': 0.9989347702728173,
#     'volume_24h': 662202.463799284}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'XMR/USDT',
#   'base_currency_id': 'xmr-monero',
#   'base_currency_name': 'monero',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/xmr_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012288776709424509,
#   'quotes': {'USD': {'price': 0.9958379392943003,
#     'volume_24h': 662024.2185198}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)},
#  {'exchange_id': 'digifinex',
#   'exchange_name': 'DigiFinex',
#   'pair': 'BTTC/USDT',
#   'base_currency_id': 'bttc-bittorrent-chain',
#   'base_currency_name': 'bittorrent chain',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/BTT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001226349161730358,
#   'quotes': {'USD': {'price': 1.0021695884537003,
#     'volume_24h': 660662.0533712769}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 47, 6)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'ZEC/USDT',
#   'base_currency_id': 'zec-zcash',
#   'base_currency_name': 'zcash',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/zec_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001220373542991904,
#   'quotes': {'USD': {'price': 0.9987756825749234,
#     'volume_24h': 657442.8522912676}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)},
#  {'exchange_id': 'deepcoin',
#   'exchange_name': 'Deepcoin',
#   'pair': 'SFP/USDT',
#   'base_currency_id': 'sfp-safepal-token',
#   'base_currency_name': 'safepal token',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.00122015873087029,
#   'quotes': {'USD': {'price': 0.999077937442839,
#     'volume_24h': 657327.1281388131}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 59)},
#  {'exchange_id': 'betconix',
#   'exchange_name': 'BETCONIX',
#   'pair': 'OMG/USDT',
#   'base_currency_id': 'omg-omg-network',
#   'base_currency_name': 'omg network',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001218879857299051,
#   'quotes': {'USD': {'price': 0.9977812384847677,
#     'volume_24h': 656638.1699970838}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 20)},
#  {'exchange_id': 'bkex',
#   'exchange_name': 'Bkex',
#   'pair': 'API3/USDT',
#   'base_currency_id': 'api3-api3',
#   'base_currency_name': 'api3',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bkex.com/trade/API3_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001218872605870916,
#   'quotes': {'USD': {'price': 1.063177054072928,
#     'volume_24h': 656634.2634886024}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 44, 20)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'DREP/USDT',
#   'base_currency_id': 'drep-drep',
#   'base_currency_name': 'drep',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/DREP_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001217777656541369,
#   'quotes': {'USD': {'price': 1.002348784343646,
#     'volume_24h': 656044.3894992279}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'ENS/USDT',
#   'base_currency_id': 'ens-ethereum-name-service',
#   'base_currency_name': 'ethereum name service',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/ens_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012165210433612225,
#   'quotes': {'USD': {'price': 0.9978892926429308,
#     'volume_24h': 655367.423534072}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)},
#  {'exchange_id': 'bitmart',
#   'exchange_name': 'BitMart',
#   'pair': 'SPELL/USDT',
#   'base_currency_id': 'spell-spell-token',
#   'base_currency_name': 'spell token',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitmart.com/trade/en?layout=basic&symbol=SPELL_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001214190250339852,
#   'quotes': {'USD': {'price': 1.000188594530806,
#     'volume_24h': 654111.7725730443}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 11)},
#  {'exchange_id': 'counos-exchange',
#   'exchange_name': 'Counos Exchange',
#   'pair': 'TRX/USDT',
#   'base_currency_id': 'trx-tron',
#   'base_currency_name': 'tron',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://counos.exchange/spot/trading/TRXUSDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0012122249849452068,
#   'quotes': {'USD': {'price': 0.9986414495430487,
#     'volume_24h': 653053.0396187087}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'gateio',
#   'exchange_name': 'Gate.io',
#   'pair': 'THETA/USDT',
#   'base_currency_id': 'theta-theta-token',
#   'base_currency_name': 'theta',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.gate.io/trade/theta_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001211897078196562,
#   'quotes': {'USD': {'price': 1.0032324100432275,
#     'volume_24h': 652876.3888306344}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)},
#  {'exchange_id': 'bitmart',
#   'exchange_name': 'BitMart',
#   'pair': 'REN/USDT',
#   'base_currency_id': 'ren-republic-protocol',
#   'base_currency_name': 'ren',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitmart.com/trade/en?layout=basic&symbol=REN_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011991144761173357,
#   'quotes': {'USD': {'price': 0.9997441754851162,
#     'volume_24h': 645990.1117403692}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 11)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'LSK/USDT',
#   'base_currency_id': 'lsk-lisk',
#   'base_currency_name': 'lisk',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/LSK_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011979533462820658,
#   'quotes': {'USD': {'price': 0.9998642057917861,
#     'volume_24h': 645364.5848144833}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'probit-exchange',
#   'exchange_name': 'ProBit Exchange',
#   'pair': 'XRP/USDT',
#   'base_currency_id': 'xrp-xrp',
#   'base_currency_name': 'xrp',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.probit.com/app/exchange/XRP-USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011838022397400725,
#   'quotes': {'USD': {'price': 0.997672298999656,
#     'volume_24h': 637741.0633923153}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 46, 21)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'ONG/USDT',
#   'base_currency_id': 'ong-ong',
#   'base_currency_name': 'ontology gas',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/ONG_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011830237429558848,
#   'quotes': {'USD': {'price': 1.0131853458734512,
#     'volume_24h': 637321.669552425}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  {'exchange_id': 'pionex',
#   'exchange_name': 'Pionex',
#   'pair': 'SLP/USDT',
#   'base_currency_id': 'slp-smooth-love-potion',
#   'base_currency_name': 'smooth love potion',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001180798327959496,
#   'quotes': {'USD': {'price': 0.9833820718986737,
#     'volume_24h': 636122.7881188185}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 20)},
#  {'exchange_id': 'bitforex',
#   'exchange_name': 'BitForex',
#   'pair': 'UNI/USDT',
#   'base_currency_id': 'uni-uniswap',
#   'base_currency_name': 'uniswap',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitforex.com/en/spot/uni_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011770558879973547,
#   'quotes': {'USD': {'price': 0.9981741686796088,
#     'volume_24h': 634106.6509964035}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 27)},
#  {'exchange_id': 'huobi-korea',
#   'exchange_name': 'Huobi Korea',
#   'pair': 'BTC/USDT',
#   'base_currency_id': 'btc-bitcoin',
#   'base_currency_name': 'bitcoin',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.huobi.co.kr/en-US/exchange/btc_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.001175788329434148,
#   'quotes': {'USD': {'price': 0.9981730115048566,
#     'volume_24h': 633423.7885056307}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 32)},
#  {'exchange_id': 'bitforex',
#   'exchange_name': 'BitForex',
#   'pair': 'TRX/USDT',
#   'base_currency_id': 'trx-tron',
#   'base_currency_name': 'tron',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bitforex.com/en/spot/trx_usdt',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011749871292892117,
#   'quotes': {'USD': {'price': 0.9992056537518299,
#     'volume_24h': 632992.163851386}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 27)},
#  {'exchange_id': 'bittilo',
#   'exchange_name': 'Bittilo',
#   'pair': 'ETH/USDT',
#   'base_currency_id': 'eth-ethereum',
#   'base_currency_name': 'ethereum',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011707610612342817,
#   'quotes': {'USD': {'price': 1.0009483429269823,
#     'volume_24h': 630715.4853278592}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 23)},
#  {'exchange_id': 'bkex',
#   'exchange_name': 'Bkex',
#   'pair': 'XCH/USDT',
#   'base_currency_id': 'xch-chia-',
#   'base_currency_name': 'chia',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.bkex.com/trade/XCH_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011616501988806933,
#   'quotes': {'USD': {'price': 1.0036193128156303,
#     'volume_24h': 625807.2575422162}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 44, 20)},
#  {'exchange_id': 'oceanex',
#   'exchange_name': 'OceanEx',
#   'pair': 'VET/USDT',
#   'base_currency_id': 'vet-vechain',
#   'base_currency_name': 'vechain',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': None,
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011482979674797334,
#   'quotes': {'USD': {'price': 0.998776745332852,
#     'volume_24h': 618614.1082420611}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 28)},
#  {'exchange_id': 'binance',
#   'exchange_name': 'Binance',
#   'pair': 'VITE/USDT',
#   'base_currency_id': 'vite-vite',
#   'base_currency_name': 'vite',
#   'quote_currency_id': 'usdt-tether',
#   'quote_currency_name': 'tether',
#   'market_url': 'https://www.binance.com/en/trade/VITE_USDT',
#   'category': 'Spot',
#   'fee_type': 'Percentage',
#   'outlier': False,
#   'adjusted_volume_24h_share': 0.0011472650966376917,
#   'quotes': {'USD': {'price': 0.9953894504917372,
#     'volume_24h': 618057.6773391298}},
#   'trust_score': 'high',
#   'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)},
#  ...]

# %%
for i in markets:
    if i['pair'] == 'DOGE/USDT':
        print(i)
# Out:
# {'exchange_id': 'digifinex', 'exchange_name': 'DigiFinex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.digifinex.com/en-ww/trade/USDT/DOGE', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.10300438061912301, 'quotes': {'USD': {'price': 0.9990057482562642, 'volume_24h': 55490791.472509705}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 47, 6)}
# {'exchange_id': 'huobi', 'exchange_name': 'Huobi', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.hbg.com/en-us/exchange/?s=doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.03387326923788781, 'quotes': {'USD': {'price': 1.0024834340267768, 'volume_24h': 18248296.902266387}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 27)}
# {'exchange_id': 'bitmart', 'exchange_name': 'BitMart', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bitmart.com/trade/en?layout=basic&symbol=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.014793210026163028, 'quotes': {'USD': {'price': 1.0019458691779426, 'volume_24h': 7969437.1039055865}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 11)}
# {'exchange_id': 'bibox', 'exchange_name': 'Bibox', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bibox.com/exchange?coinPair=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.010772295629604283, 'quotes': {'USD': {'price': 1.003673124676894, 'volume_24h': 5803279.500052863}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 46, 51)}
# {'exchange_id': 'ftx', 'exchange_name': 'FTX (Spot)', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://ftx.com/trade/DOGE/USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.00861449964064333, 'quotes': {'USD': {'price': 1.0006979449676798, 'volume_24h': 4640825.956388521}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 15)}
# {'exchange_id': 'coinex', 'exchange_name': 'CoinEx', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.coinex.com/exchange?currency=usdt&dest=doge#limit', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0056723648273401955, 'quotes': {'USD': {'price': 1.001271603797341, 'volume_24h': 3055831.333560746}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 34)}
# {'exchange_id': 'bitfinex', 'exchange_name': 'Bitfinex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bitfinex.com/t/DOGE::UST', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0028915235198478844, 'quotes': {'USD': {'price': 1.0015961367728792, 'volume_24h': 1557729.1733935028}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 50)}
# {'exchange_id': 'binance-us', 'exchange_name': 'Binance US', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.binance.us/en/trade/pro/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0027884192896875286, 'quotes': {'USD': {'price': 1.001952116619092, 'volume_24h': 1502184.5907129117}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 44)}
# {'exchange_id': 'betconix', 'exchange_name': 'BETCONIX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.001242663920147171, 'quotes': {'USD': {'price': 1.0049415572379279, 'volume_24h': 669451.1830353767}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 20)}
# {'exchange_id': 'oceanex', 'exchange_name': 'OceanEx', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0007712527325255432, 'quotes': {'USD': {'price': 1.0013402374639047, 'volume_24h': 415491.305281756}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 28)}
# {'exchange_id': 'kraken', 'exchange_name': 'Kraken', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://trade.kraken.com/charts/KRAKEN:XXDG-USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.00041636541033585506, 'quotes': {'USD': {'price': 1.0008101308359496, 'volume_24h': 224305.47149975752}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 41)}
# {'exchange_id': 'bigone', 'exchange_name': 'BigONE', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://big.one/trade/DOGE-USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0003410924665147908, 'quotes': {'USD': {'price': 1.0015836508453222, 'volume_24h': 183754.23276611912}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 7)}
# {'exchange_id': 'bittrex', 'exchange_name': 'Bittrex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://bittrex.com/Market/Index?MarketName=USDT-DOGE', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0001834270868216562, 'quotes': {'USD': {'price': 0.9989712174513588, 'volume_24h': 98816.32377235801}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 21)}
# {'exchange_id': 'bitforex', 'exchange_name': 'BitForex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bitforex.com/en/spot/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.00015885452163371964, 'quotes': {'USD': {'price': 0.9993166329582427, 'volume_24h': 85578.5266748694}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 27)}
# {'exchange_id': 'bittilo', 'exchange_name': 'Bittilo', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.4823250571305594e-05, 'quotes': {'USD': {'price': 1.0004985655128578, 'volume_24h': 29534.52607560924}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 23)}
# {'exchange_id': 'tarmex', 'exchange_name': 'Tarmex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 4.552816036602048e-05, 'quotes': {'USD': {'price': 1.0012216943126853, 'volume_24h': 24527.05057602951}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 51)}
# {'exchange_id': 'nicehash', 'exchange_name': 'NiceHash', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.2709885389427652e-05, 'quotes': {'USD': {'price': 0.995848256116882, 'volume_24h': 6847.102963437367}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 44)}
# {'exchange_id': 'zonda', 'exchange_name': 'Zonda', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://app.bitbay.net/market/doge-usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 9.577321336235583e-06, 'quotes': {'USD': {'price': 0.9680241605743447, 'volume_24h': 5159.519798477398}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 55)}
# {'exchange_id': 'coinamount', 'exchange_name': 'CoinAmount', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 7.910595170446222e-06, 'quotes': {'USD': {'price': 1.0001871941181382, 'volume_24h': 4261.616684535247}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 6)}
# {'exchange_id': 'novadax', 'exchange_name': 'NovaDAX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.241518820805727e-06, 'quotes': {'USD': {'price': 1.0093597651194728, 'volume_24h': 1746.279564600887}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 53)}
# {'exchange_id': 'upbit', 'exchange_name': 'Upbit', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://upbit.com/exchange?code=CRIX.UPBIT.USDT-DOGE', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.1112496058876645e-06, 'quotes': {'USD': {'price': 0.9987838238927831, 'volume_24h': 1676.1005897179125}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 21)}
# {'exchange_id': 'bitubu', 'exchange_name': 'BitUBU', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://bitubu.com/trading/dogeusdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.061579879590508e-06, 'quotes': {'USD': {'price': 1.0005608630574103, 'volume_24h': 1649.3423838252552}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 25)}
# {'exchange_id': 'yobit', 'exchange_name': 'YoBit', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://yobit.net/en/trade/DOGE/USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 2.382053719465985e-06, 'quotes': {'USD': {'price': 0.999525240392396, 'volume_24h': 1283.2662594416222}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 47, 45)}
# {'exchange_id': 'crex24', 'exchange_name': 'Crex24', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://crex24.com/exchange/DOGE-USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 2.270531956061388e-08, 'quotes': {'USD': {'price': 0.9777904016491424, 'volume_24h': 12.231869610609651}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 28)}
# {'exchange_id': 'exchangeassets', 'exchange_name': 'ExchangeAssets', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 7.295883219368706e-11, 'quotes': {'USD': {'price': 1.006830041397369, 'volume_24h': 0.03930457441715926}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 20)}
# {'exchange_id': 'bkex', 'exchange_name': 'Bkex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bkex.com/trade/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': True, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.0863309532654144, 'volume_24h': 75555153.59277247}}, 'trust_score': 'high', 'last_updated': datetime.datetime(2022, 8, 15, 3, 44, 20)}
# {'exchange_id': 'dex-trade', 'exchange_name': 'Dex-Trade', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.010975349442679637, 'quotes': {'USD': {'price': 1.0005608630574103, 'volume_24h': 5912669.185533584}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 44)}
# {'exchange_id': 'cointiger', 'exchange_name': 'CoinTiger', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.cointiger.com/en-us/#/trade_pro?coin=doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.006353254442817274, 'quotes': {'USD': {'price': 1.0011081687686052, 'volume_24h': 3422641.9822063176}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 5)}
# {'exchange_id': 'poloniex', 'exchange_name': 'Poloniex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://poloniex.com/exchange/#usdt_doge', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0008739861242478304, 'quotes': {'USD': {'price': 1.0004736486671155, 'volume_24h': 470836.1089013676}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 3)}
# {'exchange_id': 'huobi-korea', 'exchange_name': 'Huobi Korea', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.huobi.co.kr/en-US/exchange/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.00048385761681709173, 'quotes': {'USD': {'price': 1.0028838567979383, 'volume_24h': 260665.05090170936}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 32)}
# {'exchange_id': 'exbitron', 'exchange_name': 'Exbitron', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 4.528598029540475e-07, 'quotes': {'USD': {'price': 0.9827456306829085, 'volume_24h': 243.96582689940007}}, 'trust_score': 'medium', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 8)}
# {'exchange_id': 'binance', 'exchange_name': 'Binance', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.binance.com/en/trade/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.509322225182839, 'quotes': {'USD': {'price': 1.0010595228446306, 'volume_24h': 274383411.85159767}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)}
# {'exchange_id': 'gateio', 'exchange_name': 'Gate.io', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.gate.io/trade/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.13746956153833678, 'quotes': {'USD': {'price': 1.0011842654642995, 'volume_24h': 74057964.59616764}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 4)}
# {'exchange_id': 'dsdaq-global', 'exchange_name': 'Dsdaq Global', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.dsdaq.io/en_US/trade/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.12741285946007205, 'quotes': {'USD': {'price': 1.0032468910662562, 'volume_24h': 68640191.54057644}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 49)}
# {'exchange_id': 'okx', 'exchange_name': 'OKX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.okx.com/trade-spot/doge-usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.12552379925909204, 'quotes': {'USD': {'price': 1.0025584889382335, 'volume_24h': 67622512.04906812}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 59)}
# {'exchange_id': 'deepcoin', 'exchange_name': 'Deepcoin', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.028229438249792703, 'quotes': {'USD': {'price': 1.003059142365918, 'volume_24h': 15207837.393806111}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 59)}
# {'exchange_id': 'p2pb2b', 'exchange_name': 'P2PB2B', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://p2pb2b.com/trade/DOGE_USDT/', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.01677714927742601, 'quotes': {'USD': {'price': 0.998074997559131, 'volume_24h': 9038230.087507322}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 12)}
# {'exchange_id': 'btcix', 'exchange_name': 'Btcix', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://btcix.io/Trade/index/market/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0134844114004959, 'quotes': {'USD': {'price': 1.0018084451809233, 'volume_24h': 7264357.657964832}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 54)}
# {'exchange_id': 'latoken', 'exchange_name': 'LATOKEN', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.010059497336721021, 'quotes': {'USD': {'price': 1.0026836054350434, 'volume_24h': 5419278.924595757}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 37)}
# {'exchange_id': 'counos-exchange', 'exchange_name': 'Counos Exchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://counos.exchange/spot/trading/DOGEUSDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.005612765425927262, 'quotes': {'USD': {'price': 1.0010595228446306, 'volume_24h': 3023723.786912604}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 1)}
# {'exchange_id': 'catex', 'exchange_name': 'Catex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.catex.io/trading/DOGE/USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0051205047231480325, 'quotes': {'USD': {'price': 1.0011343646859974, 'volume_24h': 2758531.8033887297}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 30)}
# {'exchange_id': 'bw', 'exchange_name': 'BW', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.bw.com/trade/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0013629625942275997, 'quotes': {'USD': {'price': 1.0712671640468006, 'volume_24h': 734258.801873455}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 8)}
# {'exchange_id': 'hitbtc', 'exchange_name': 'HitBTC', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://hitbtc.com/DOGE-to-USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 2.794126380197573e-05, 'quotes': {'USD': {'price': 3.7456893847790234, 'volume_24h': 15052.591295578046}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 39)}
# {'exchange_id': 'xbts', 'exchange_name': 'XBTS', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 7.4180164832352444e-09, 'quotes': {'USD': {'price': 1.0043129662938755, 'volume_24h': 3.9962533956000152}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 12)}
# {'exchange_id': 'zbcom', 'exchange_name': 'ZB.COM', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://trans.zb.com/dogeusdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': True, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.281262704636114, 'volume_24h': 15572403.586612718}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 59)}
# {'exchange_id': 'binance-futures', 'exchange_name': 'Binance Futures', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Derivatives', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.0026836054350434, 'volume_24h': 1287842651.8983204}}, 'trust_score': 'low', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 34)}
# {'exchange_id': 'mexc', 'exchange_name': 'MEXC', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.mexc.com/exchange/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.2157528961007829, 'quotes': {'USD': {'price': 1.0033447386211063, 'volume_24h': 116230968.96614814}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 51)}
# {'exchange_id': 'zedxion-exchange', 'exchange_name': 'ZEDXION EXCHANGE', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.12802861614270544, 'quotes': {'USD': {'price': 1.002370497565905, 'volume_24h': 68971913.60393372}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 45)}
# {'exchange_id': 'btc6x-exchange', 'exchange_name': 'BTC6X Exchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.006151527624096914, 'quotes': {'USD': {'price': 1.0028087531641294, 'volume_24h': 3313967.1786228083}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 35)}
# {'exchange_id': 'tidex', 'exchange_name': 'Tidex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://tidex.com/exchange/doge/usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.005407570267264156, 'quotes': {'USD': {'price': 1.0012528871575006, 'volume_24h': 2913180.510091724}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 20)}
# {'exchange_id': 'bitexlive', 'exchange_name': 'Bitexlive', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://bitexlive.com/exchange/USDT-DOGE', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.002501251917172764, 'quotes': {'USD': {'price': 1.0157961455589224, 'volume_24h': 1347481.0267465564}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 5)}
# {'exchange_id': 'bitcom', 'exchange_name': 'Bit.com', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0022374380110334953, 'quotes': {'USD': {'price': 1.0018084451809233, 'volume_24h': 1205358.5037516016}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 31)}
# {'exchange_id': 'btc-alpha', 'exchange_name': 'BTC-Alpha', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://btc-alpha.com/exchange/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0019162670628820012, 'quotes': {'USD': {'price': 1.1343843068816983, 'volume_24h': 1032336.4438762752}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 45)}
# {'exchange_id': 'gokumarket', 'exchange_name': 'GokuMarket', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://gokumarket.com/exchange/DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.001203907097822693, 'quotes': {'USD': {'price': 1.2033104283886482, 'volume_24h': 648572.0055400319}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 3)}
# {'exchange_id': 'decoin', 'exchange_name': 'Decoin', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.001122076294666237, 'quotes': {'USD': {'price': 1.0013090391763464, 'volume_24h': 604487.8995370697}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 8)}
# {'exchange_id': 'hollaex', 'exchange_name': 'HollaEx', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0006826878845813536, 'quotes': {'USD': {'price': 1.0004985655128578, 'volume_24h': 367779.41691811517}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 6)}
# {'exchange_id': 'criptoswaps', 'exchange_name': 'Criptoswaps', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.00044840052053550386, 'quotes': {'USD': {'price': 0.998074997559131, 'volume_24h': 241563.51051909567}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 16)}
# {'exchange_id': 'smartfi', 'exchange_name': 'SmartFi', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0003171406564016526, 'quotes': {'USD': {'price': 1.005066766368652, 'volume_24h': 170850.8504789919}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 53)}
# {'exchange_id': 'dasset', 'exchange_name': 'Dasset', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0.0001834270868216562, 'quotes': {'USD': {'price': 0.9989712174513588, 'volume_24h': 98816.32377235801}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48)}
# {'exchange_id': 'garts-exchange', 'exchange_name': 'Garts Exchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 9.745507706814999e-05, 'quotes': {'USD': {'price': 1.0029339321371868, 'volume_24h': 52501.25603417387}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 40)}
# {'exchange_id': 'cex-trade', 'exchange_name': 'Cex-Trade', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 8.278809918377984e-05, 'quotes': {'USD': {'price': 1.002420896851069, 'volume_24h': 44599.82304247452}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 11)}
# {'exchange_id': 'patriot-exchange', 'exchange_name': 'Patriot Exchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.4823250571305594e-05, 'quotes': {'USD': {'price': 1.0004985655128578, 'volume_24h': 29534.52607560924}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 5)}
# {'exchange_id': 'bitunivex', 'exchange_name': 'Bitunivex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.4823250571305594e-05, 'quotes': {'USD': {'price': 1.0004985655128578, 'volume_24h': 29534.52607560924}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 46)}
# {'exchange_id': 'krypterz', 'exchange_name': 'Krypterz', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.4823250571305594e-05, 'quotes': {'USD': {'price': 1.0004985655128578, 'volume_24h': 29534.52607560924}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 45)}
# {'exchange_id': '365-stream', 'exchange_name': '365 stream', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 3.0899624516576294e-05, 'quotes': {'USD': {'price': 1.003184383862031, 'volume_24h': 16646.327178728316}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 17)}
# {'exchange_id': 'xeggex', 'exchange_name': 'Xeggex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 6.342702820491278e-06, 'quotes': {'USD': {'price': 1.003059142365918, 'volume_24h': 3416.957584410135}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 48)}
# {'exchange_id': 'southxchange', 'exchange_name': 'SouthXchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.southxchange.com/Market/Book/DOGE/USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 1.0449188671046019e-06, 'quotes': {'USD': {'price': 0.9892394304720575, 'volume_24h': 562.9214467547392}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 52)}
# {'exchange_id': 'bololex', 'exchange_name': 'Bololex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 8.24945204759998e-08, 'quotes': {'USD': {'price': 1.2360765461489651, 'volume_24h': 44.44166554707217}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 34)}
# {'exchange_id': 'graviex', 'exchange_name': 'Graviex', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://graviex.net/markets/dogeusdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 6.216981950155294e-08, 'quotes': {'USD': {'price': 0.9919140407840746, 'volume_24h': 33.49228905710995}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 25)}
# {'exchange_id': 'fatbtc', 'exchange_name': 'Fatbtc', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.fatbtc.com', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 4.703992927054081e-08, 'quotes': {'USD': {'price': 1.0131654998488044, 'volume_24h': 25.341474705674614}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 28)}
# {'exchange_id': 'zebitex', 'exchange_name': 'ZEBITEX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 7.955389420303346e-09, 'quotes': {'USD': {'price': 0.9924655330512677, 'volume_24h': 4.285748360907152}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 26)}
# {'exchange_id': 'satoexchange', 'exchange_name': 'SatoExchange', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 5.563515685425346e-10, 'quotes': {'USD': {'price': 0.08927424754273433, 'volume_24h': 0.2997191836874746}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 36)}
# {'exchange_id': 'apollox', 'exchange_name': 'ApolloX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Derivatives', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.0021833267245859, 'volume_24h': 1468725.4103869104}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 59)}
# {'exchange_id': 'altmarkets', 'exchange_name': 'AltMarkets', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.093129610506312, 'volume_24h': 0}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 20)}
# {'exchange_id': 'exchangily', 'exchange_name': 'eXchangily', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': None, 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 0.20086259325877512, 'volume_24h': 0}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 12)}
# {'exchange_id': 'bankcex', 'exchange_name': 'BankCEX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://bankcex.com/exchange-base.html?symbol=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 0.5356335820234003, 'volume_24h': 0}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 30)}
# {'exchange_id': 'vindax', 'exchange_name': 'VinDAX', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://vindax.com/exchange-base.html?symbol=DOGE_USDT', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': False, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.0300645808142315, 'volume_24h': 0}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 3)}
# {'exchange_id': 'zbg', 'exchange_name': 'ZBG', 'pair': 'DOGE/USDT', 'base_currency_id': 'doge-dogecoin', 'base_currency_name': 'dogecoin', 'quote_currency_id': 'usdt-tether', 'quote_currency_name': 'tether', 'market_url': 'https://www.zbg.com/trade/doge_usdt', 'category': 'Spot', 'fee_type': 'Percentage', 'outlier': True, 'adjusted_volume_24h_share': 0, 'quotes': {'USD': {'price': 1.2803867581108395, 'volume_24h': 4607909.986806497}}, 'trust_score': 'no_data', 'last_updated': datetime.datetime(2022, 8, 15, 3, 48, 48)}

# %%
api_client = Coinpaprika.Client()
btc_ticker = api_client.tickers.for_coin("doge-dogecoin")

# %%
btc_ticker
# Out:
# {'id': 'doge-dogecoin',
#  'name': 'Dogecoin',
#  'symbol': 'DOGE',
#  'rank': 11,
#  'circulating_supply': 132670764300,
#  'total_supply': 132670764300,
#  'max_supply': 0,
#  'beta_value': 1.06227,
#  'first_data_at': datetime.datetime(2013, 12, 15, 0, 0),
#  'last_updated': datetime.datetime(2022, 8, 10, 9, 53, 29),
#  'quotes': {'USD': {'price': 0.0685101251421323,
#    'volume_24h': 324293326.2286597,
#    'volume_24h_change_24h': -17.57,
#    'market_cap': 9089290665,
#    'market_cap_change_24h': -3.38,
#    'percent_change_15m': 0.02,
#    'percent_change_30m': -0.21,
#    'percent_change_1h': -0.08,
#    'percent_change_6h': 0.51,
#    'percent_change_12h': -1.15,
#    'percent_change_24h': -3.38,
#    'percent_change_7d': 0.87,
#    'percent_change_30d': 11.19,
#    'percent_change_1y': -74.32,
#    'ath_price': 0.75287027,
#    'ath_date': '2021-05-08T05:02:22Z',
#    'percent_from_price_ath': -90.9}}}
